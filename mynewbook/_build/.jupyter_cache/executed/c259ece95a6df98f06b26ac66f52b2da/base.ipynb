# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn import metrics
from sklearn.metrics import ConfusionMatrixDisplay

#Estilizar conteúdo
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def estilo_tabelas(df, max_altura='300px', casas_decimais=3):
    def cor_linhas(row):
        if row.name % 2 == 0:
            return ['background-color: #ffffff'] * len(row)
        else:
            return ['background-color: #f9f9f9'] * len(row)
    
    return (
        df.style.apply(cor_linhas, axis=1) 
        .set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},  # Azul abaixo do nome das colunas
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '300px')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},
            ]
        )
        .set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        )
        .set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'  
        )
        .format(
            precision=casas_decimais  
        )
    )

# Base de dados

df_eventos_2010_2017_modelo1 = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_2010_2017_modelo1.csv",
    sep=';',
    decimal=',',
)

# %%
# Remover linhas com dados ausentes

df_eventos_2018_2024_modelo1 = df_eventos_2010_2017_modelo1.dropna()

estilo_tabelas(df_eventos_2010_2017_modelo1.head(5))
# Out:
# <style type="text/css">
# #T_ebec7 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_ebec7 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 300px;
# }
# #T_ebec7 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_ebec7 td {
#   border: 1px solid #666;
# }
# #T_ebec7  th {
#   border: 1px solid #666;
# }
# #T_ebec7_row0_col0, #T_ebec7_row0_col1, #T_ebec7_row0_col2, #T_ebec7_row0_col3, #T_ebec7_row0_col4, #T_ebec7_row0_col5, #T_ebec7_row0_col6, #T_ebec7_row0_col7, #T_ebec7_row0_col8, #T_ebec7_row0_col9, #T_ebec7_row0_col10, #T_ebec7_row0_col11, #T_ebec7_row0_col12, #T_ebec7_row0_col13, #T_ebec7_row0_col14, #T_ebec7_row0_col15, #T_ebec7_row0_col16, #T_ebec7_row0_col17, #T_ebec7_row0_col18, #T_ebec7_row0_col19, #T_ebec7_row0_col20, #T_ebec7_row0_col21, #T_ebec7_row0_col22, #T_ebec7_row0_col23, #T_ebec7_row0_col24, #T_ebec7_row0_col25, #T_ebec7_row0_col26, #T_ebec7_row0_col27, #T_ebec7_row0_col28, #T_ebec7_row0_col29, #T_ebec7_row0_col30, #T_ebec7_row0_col31, #T_ebec7_row0_col32, #T_ebec7_row0_col33, #T_ebec7_row0_col34, #T_ebec7_row0_col35, #T_ebec7_row0_col36, #T_ebec7_row0_col37, #T_ebec7_row0_col38, #T_ebec7_row0_col39, #T_ebec7_row0_col40, #T_ebec7_row0_col41, #T_ebec7_row0_col42, #T_ebec7_row0_col43, #T_ebec7_row0_col44, #T_ebec7_row0_col45, #T_ebec7_row0_col46, #T_ebec7_row0_col47, #T_ebec7_row0_col48, #T_ebec7_row0_col49, #T_ebec7_row0_col50, #T_ebec7_row0_col51, #T_ebec7_row0_col52, #T_ebec7_row0_col53, #T_ebec7_row0_col54, #T_ebec7_row0_col55, #T_ebec7_row2_col0, #T_ebec7_row2_col1, #T_ebec7_row2_col2, #T_ebec7_row2_col3, #T_ebec7_row2_col4, #T_ebec7_row2_col5, #T_ebec7_row2_col6, #T_ebec7_row2_col7, #T_ebec7_row2_col8, #T_ebec7_row2_col9, #T_ebec7_row2_col10, #T_ebec7_row2_col11, #T_ebec7_row2_col12, #T_ebec7_row2_col13, #T_ebec7_row2_col14, #T_ebec7_row2_col15, #T_ebec7_row2_col16, #T_ebec7_row2_col17, #T_ebec7_row2_col18, #T_ebec7_row2_col19, #T_ebec7_row2_col20, #T_ebec7_row2_col21, #T_ebec7_row2_col22, #T_ebec7_row2_col23, #T_ebec7_row2_col24, #T_ebec7_row2_col25, #T_ebec7_row2_col26, #T_ebec7_row2_col27, #T_ebec7_row2_col28, #T_ebec7_row2_col29, #T_ebec7_row2_col30, #T_ebec7_row2_col31, #T_ebec7_row2_col32, #T_ebec7_row2_col33, #T_ebec7_row2_col34, #T_ebec7_row2_col35, #T_ebec7_row2_col36, #T_ebec7_row2_col37, #T_ebec7_row2_col38, #T_ebec7_row2_col39, #T_ebec7_row2_col40, #T_ebec7_row2_col41, #T_ebec7_row2_col42, #T_ebec7_row2_col43, #T_ebec7_row2_col44, #T_ebec7_row2_col45, #T_ebec7_row2_col46, #T_ebec7_row2_col47, #T_ebec7_row2_col48, #T_ebec7_row2_col49, #T_ebec7_row2_col50, #T_ebec7_row2_col51, #T_ebec7_row2_col52, #T_ebec7_row2_col53, #T_ebec7_row2_col54, #T_ebec7_row2_col55, #T_ebec7_row4_col0, #T_ebec7_row4_col1, #T_ebec7_row4_col2, #T_ebec7_row4_col3, #T_ebec7_row4_col4, #T_ebec7_row4_col5, #T_ebec7_row4_col6, #T_ebec7_row4_col7, #T_ebec7_row4_col8, #T_ebec7_row4_col9, #T_ebec7_row4_col10, #T_ebec7_row4_col11, #T_ebec7_row4_col12, #T_ebec7_row4_col13, #T_ebec7_row4_col14, #T_ebec7_row4_col15, #T_ebec7_row4_col16, #T_ebec7_row4_col17, #T_ebec7_row4_col18, #T_ebec7_row4_col19, #T_ebec7_row4_col20, #T_ebec7_row4_col21, #T_ebec7_row4_col22, #T_ebec7_row4_col23, #T_ebec7_row4_col24, #T_ebec7_row4_col25, #T_ebec7_row4_col26, #T_ebec7_row4_col27, #T_ebec7_row4_col28, #T_ebec7_row4_col29, #T_ebec7_row4_col30, #T_ebec7_row4_col31, #T_ebec7_row4_col32, #T_ebec7_row4_col33, #T_ebec7_row4_col34, #T_ebec7_row4_col35, #T_ebec7_row4_col36, #T_ebec7_row4_col37, #T_ebec7_row4_col38, #T_ebec7_row4_col39, #T_ebec7_row4_col40, #T_ebec7_row4_col41, #T_ebec7_row4_col42, #T_ebec7_row4_col43, #T_ebec7_row4_col44, #T_ebec7_row4_col45, #T_ebec7_row4_col46, #T_ebec7_row4_col47, #T_ebec7_row4_col48, #T_ebec7_row4_col49, #T_ebec7_row4_col50, #T_ebec7_row4_col51, #T_ebec7_row4_col52, #T_ebec7_row4_col53, #T_ebec7_row4_col54, #T_ebec7_row4_col55 {
#   background-color: #ffffff;
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# #T_ebec7_row1_col0, #T_ebec7_row1_col1, #T_ebec7_row1_col2, #T_ebec7_row1_col3, #T_ebec7_row1_col4, #T_ebec7_row1_col5, #T_ebec7_row1_col6, #T_ebec7_row1_col7, #T_ebec7_row1_col8, #T_ebec7_row1_col9, #T_ebec7_row1_col10, #T_ebec7_row1_col11, #T_ebec7_row1_col12, #T_ebec7_row1_col13, #T_ebec7_row1_col14, #T_ebec7_row1_col15, #T_ebec7_row1_col16, #T_ebec7_row1_col17, #T_ebec7_row1_col18, #T_ebec7_row1_col19, #T_ebec7_row1_col20, #T_ebec7_row1_col21, #T_ebec7_row1_col22, #T_ebec7_row1_col23, #T_ebec7_row1_col24, #T_ebec7_row1_col25, #T_ebec7_row1_col26, #T_ebec7_row1_col27, #T_ebec7_row1_col28, #T_ebec7_row1_col29, #T_ebec7_row1_col30, #T_ebec7_row1_col31, #T_ebec7_row1_col32, #T_ebec7_row1_col33, #T_ebec7_row1_col34, #T_ebec7_row1_col35, #T_ebec7_row1_col36, #T_ebec7_row1_col37, #T_ebec7_row1_col38, #T_ebec7_row1_col39, #T_ebec7_row1_col40, #T_ebec7_row1_col41, #T_ebec7_row1_col42, #T_ebec7_row1_col43, #T_ebec7_row1_col44, #T_ebec7_row1_col45, #T_ebec7_row1_col46, #T_ebec7_row1_col47, #T_ebec7_row1_col48, #T_ebec7_row1_col49, #T_ebec7_row1_col50, #T_ebec7_row1_col51, #T_ebec7_row1_col52, #T_ebec7_row1_col53, #T_ebec7_row1_col54, #T_ebec7_row1_col55, #T_ebec7_row3_col0, #T_ebec7_row3_col1, #T_ebec7_row3_col2, #T_ebec7_row3_col3, #T_ebec7_row3_col4, #T_ebec7_row3_col5, #T_ebec7_row3_col6, #T_ebec7_row3_col7, #T_ebec7_row3_col8, #T_ebec7_row3_col9, #T_ebec7_row3_col10, #T_ebec7_row3_col11, #T_ebec7_row3_col12, #T_ebec7_row3_col13, #T_ebec7_row3_col14, #T_ebec7_row3_col15, #T_ebec7_row3_col16, #T_ebec7_row3_col17, #T_ebec7_row3_col18, #T_ebec7_row3_col19, #T_ebec7_row3_col20, #T_ebec7_row3_col21, #T_ebec7_row3_col22, #T_ebec7_row3_col23, #T_ebec7_row3_col24, #T_ebec7_row3_col25, #T_ebec7_row3_col26, #T_ebec7_row3_col27, #T_ebec7_row3_col28, #T_ebec7_row3_col29, #T_ebec7_row3_col30, #T_ebec7_row3_col31, #T_ebec7_row3_col32, #T_ebec7_row3_col33, #T_ebec7_row3_col34, #T_ebec7_row3_col35, #T_ebec7_row3_col36, #T_ebec7_row3_col37, #T_ebec7_row3_col38, #T_ebec7_row3_col39, #T_ebec7_row3_col40, #T_ebec7_row3_col41, #T_ebec7_row3_col42, #T_ebec7_row3_col43, #T_ebec7_row3_col44, #T_ebec7_row3_col45, #T_ebec7_row3_col46, #T_ebec7_row3_col47, #T_ebec7_row3_col48, #T_ebec7_row3_col49, #T_ebec7_row3_col50, #T_ebec7_row3_col51, #T_ebec7_row3_col52, #T_ebec7_row3_col53, #T_ebec7_row3_col54, #T_ebec7_row3_col55 {
#   background-color: #f9f9f9;
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_ebec7" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebec7_level0_col0" class="col_heading level0 col0" >Status</th>
#       <th id="T_ebec7_level0_col1" class="col_heading level0 col1" >DH_total_danos_humanos</th>
#       <th id="T_ebec7_level0_col2" class="col_heading level0 col2" >DM_total_danos_materiais</th>
#       <th id="T_ebec7_level0_col3" class="col_heading level0 col3" >PEPL_total_publico</th>
#       <th id="T_ebec7_level0_col4" class="col_heading level0 col4" >PEPR_total_privado</th>
#       <th id="T_ebec7_level0_col5" class="col_heading level0 col5" >regiao_Centro-oeste</th>
#       <th id="T_ebec7_level0_col6" class="col_heading level0 col6" >regiao_Nordeste</th>
#       <th id="T_ebec7_level0_col7" class="col_heading level0 col7" >regiao_Norte</th>
#       <th id="T_ebec7_level0_col8" class="col_heading level0 col8" >regiao_Sudeste</th>
#       <th id="T_ebec7_level0_col9" class="col_heading level0 col9" >regiao_Sul</th>
#       <th id="T_ebec7_level0_col10" class="col_heading level0 col10" >COBRADE_11110</th>
#       <th id="T_ebec7_level0_col11" class="col_heading level0 col11" >COBRADE_11120</th>
#       <th id="T_ebec7_level0_col12" class="col_heading level0 col12" >COBRADE_11311</th>
#       <th id="T_ebec7_level0_col13" class="col_heading level0 col13" >COBRADE_11312</th>
#       <th id="T_ebec7_level0_col14" class="col_heading level0 col14" >

# %%
X_2010_2017_modelo1 = df_eventos_2010_2017_modelo1.drop('Status', axis=1)

y_2010_2017_modelo1 = df_eventos_2010_2017_modelo1['Status']

X_train_2010_2017_modelo1, X_test_2010_2017_modelo1, y_train_2010_2017_modelo1, y_test_2010_2017_modelo1 = train_test_split(X_2010_2017_modelo1, y_2010_2017_modelo1, test_size=0.2, random_state=1, stratify=y_2010_2017_modelo1)

# %%
# Criar pipeline com normalização e modelo de Regressão Logística
pipeline_2010_2017_modelo1 = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(random_state=1, solver='lbfgs'))
])

# Definir hiperparâmetros para o Grid Search
param_grid_2010_2017_modelo1 = {
    'logreg__C': [0.01, 0.1, 1, 10],  # Regularização
    'logreg__max_iter': [1000],  # Número máximo de iterações
    'logreg__fit_intercept': [True, False],  # Se deve ajustar o intercepto
    'logreg__tol': [1e-4, 1e-3],  # Tolerância para convergência
    'logreg__penalty': ['l1', 'l2'],  # Tipos de penalidade
}

# Grid Search com validação cruzada
grid_search_2010_2017_modelo1 = GridSearchCV(pipeline_2010_2017_modelo1, param_grid_2010_2017_modelo1, cv=3, scoring='f1_weighted', n_jobs=-1)
1
grid_search_2010_2017_modelo1.fit(X_train_2010_2017_modelo1, y_train_2010_2017_modelo1)

# Melhor modelo encontrado
logreg_best_2010_2017_modelo1 = grid_search_2010_2017_modelo1.best_estimator_

print(f"Melhores hiperparâmetros: {grid_search_2010_2017_modelo1.best_params_}")

# F1 score no conjunto de teste
y_pred_2010_2017_modelo1 = logreg_best_2010_2017_modelo1.predict(X_test_2010_2017_modelo1)

f1_2010_2017_modelo1 = f1_score(y_test_2010_2017_modelo1, y_pred_2010_2017_modelo1, average='weighted')
print(f"F1 Score: {f1_2010_2017_modelo1:.6f}")

classification_report_2010_2017_modelo1 = metrics.classification_report(y_test_2010_2017_modelo1, y_pred_2010_2017_modelo1, digits=6, target_names=['Reconhecido', 'Não reconhecido'])
print('Classification report para modelo 1 (2010 - 2017): \n')
print(classification_report_2010_2017_modelo1)
# Out:
# Melhores hiperparâmetros: {'logreg__C': 1, 'logreg__fit_intercept': False, 'logreg__max_iter': 1000, 'logreg__penalty': 'l2', 'logreg__tol': 0.0001}
# F1 Score: 0.875884
# Classification report para modelo 1 (2010 - 2017):
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.913793  0.986881  0.948932      2363
# Não reconhecido   0.465517  0.109312  0.177049       247
#
#        accuracy                       0.903831      2610
#       macro avg   0.689655  0.548096  0.562991      2610
#    weighted avg   0.871370  0.903831  0.875884      2610

# %%
ConfusionMatrixDisplay.from_estimator(grid_search_2010_2017_modelo1, X_test_2010_2017_modelo1, y_test_2010_2017_modelo1, 
                                      values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])

# %%
smote = SMOTE(random_state=1)
X_train_smote_2010_2017_modelo1_, y_train_smote_2010_2017_modelo1 = smote.fit_resample(X_train_2010_2017_modelo1, y_train_2010_2017_modelo1)

pipeline_2010_2017_modelo1 = Pipeline([
    ('scaler', StandardScaler()), 
    ('logreg', LogisticRegression(random_state=1, solver='lbfgs'))  
])

# Definir hiperparâmetros para o Grid Search
param_grid_2010_2017_modelo1 = {
    'logreg__C': [0.01, 0.1, 1, 10],  
    'logreg__max_iter': [1000],  
    'logreg__fit_intercept': [True, False],
    'logreg__tol': [1e-4, 1e-3],
    'logreg__penalty': ['l1', 'l2'],
}

# Grid Search com validação cruzada
grid_search_2010_2017_modelo1 = GridSearchCV(pipeline_2010_2017_modelo1, param_grid_2010_2017_modelo1, cv=3, scoring='f1_weighted', n_jobs=-1)

# Treinar o pipeline com Grid Search
grid_search_2010_2017_modelo1.fit(X_train_smote_2010_2017_modelo1_, y_train_smote_2010_2017_modelo1)

# Melhor modelo encontrado
logreg_best_2010_2017_modelo1 = grid_search_2010_2017_modelo1.best_estimator_

print(f"Melhores hiperparâmetros: {grid_search_2010_2017_modelo1.best_params_}")

# F1 score no conjunto de teste
y_pred_2010_2017_modelo1_smote = logreg_best_2010_2017_modelo1.predict(X_test_2010_2017_modelo1)

f1_smote_2010_2017_modelo1 = f1_score(y_test_2010_2017_modelo1, y_pred_2010_2017_modelo1_smote, average='weighted')
print(f"F1 Score: {f1_smote_2010_2017_modelo1:.6f}")

classification_report_smote_2010_2017_modelo1 = metrics.classification_report(y_test_2010_2017_modelo1, y_pred_2010_2017_modelo1_smote, digits=6, target_names=['Reconhecido', 'Não reconhecido'])
print('Classification report para modelo 1 com smote (2010 - 2017): \n')
print(classification_report_smote_2010_2017_modelo1)
# Out:
# Melhores hiperparâmetros: {'logreg__C': 10, 'logreg__fit_intercept': True, 'logreg__max_iter': 1000, 'logreg__penalty': 'l2', 'logreg__tol': 0.001}
# F1 Score: 0.798037
# Classification report para modelo 1 com smote (2010 - 2017):
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.947808  0.768515  0.848796      2363
# Não reconhecido   0.211816  0.595142  0.312434       247
#
#        accuracy                       0.752107      2610
#       macro avg   0.579812  0.681828  0.580615      2610
#    weighted avg   0.878157  0.752107  0.798037      2610
