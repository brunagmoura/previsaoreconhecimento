# %%
import pandas as pd
# Exibir todas as linhas
pd.set_option('display.max_rows', None)

# Exibir todas as colunas
pd.set_option('display.max_columns', None)

# Ajustar a largura das colunas para caber o conteúdo
pd.set_option('display.max_colwidth', None)

# Desativar o uso de reticências para truncar colunas
pd.set_option('display.expand_frame_repr', False)

# %%
object_columns = ['Protocolo_S2iD', 'Nome_Municipio', 'Sigla_UF', 'regiao',
                  'Setores Censitários', 'Status', 'DH_Descricao', 'DM_Descricao',
                  'DA_Descricao', 'DA_Polui/cont da água', 'DA_Polui/cont do ar',
                  'DA_Polui/cont do solo', 'DA_Dimi/exauri hídrico',
                  "DA_Incêndi parques/APA's/APP's", 'PEPL_Descricao', 'PEPR_Descricao',
                  'Categoria', 'Grupo', 'Subgrupo', 'Tipo', 'Subtipo']

dtype = {col: 'object' for col in object_columns}

df_eventos = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_desastres_rec_nrec.csv",
    sep=';',
    decimal=',',
    dtype=dtype)

df_eventos.head(5)
# Out:
#                 Protocolo_S2iD     Nome_Municipio Sigla_UF        regiao        Data_Registro Data_Evento  codigo_ibge Setores Censitários           Status                                                                                                                                                                                                                                                                                                                                                                                                                                                               DH_Descricao  DH_MORTOS  DH_FERIDOS  DH_ENFERMOS  DH_DESABRIGADOS  DH_DESALOJADOS  DH_DESAPARECIDOS  DH_OUTROS AFETADOS  DH_total_danos_humanos                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       DM_Descricao  DM_Uni Habita Danificadas  DM_Uni Habita Destruidas  DM_Uni Habita Valor  DM_Inst Saúde Danificadas  DM_Inst Saúde Destruidas  DM_Inst Saúde Valor  DM_Inst Ensino Danificadas  DM_Inst Ensino Destruidas  DM_Inst Ensino Valor  DM_Inst Serviços Danificadas  DM_Inst Serviços Destruidas  DM_Inst Serviços Valor  DM_Inst Comuni Danificadas  DM_Inst Comuni Destruidas  DM_Inst Comuni Valor  DM_Obras de Infra Danificadas  DM_Obras de Infra Destruidas  DM_Obras de Infra Valor  DM_total_danos_materiais                                                                                                                                                                                                                                                             DA_Descricao DA_Polui/cont da água DA_Polui/cont do ar DA_Polui/cont do solo DA_Dimi/exauri hídrico DA_Incêndi parques/APA's/APP's                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     PEPL_Descricao  PEPL_Assis_méd e emergên(R$)  PEPL_Abast de água pot(R$)  PEPL_sist de esgotos sanit(R$)  PEPL_Sis limp e rec lixo (R$)  PEPL_Sis cont pragas (R$)  PEPL_distrib energia (R$)  PEPL_Telecomunicações (R$)  PEPL_Tran loc/reg/l_curso (R$)  PEPL_Distrib combustíveis(R$)  PEPL_Segurança pública (R$)  PEPL_Ensino (R$)  PEPL_total_publico                                                                                                                                                                                                                                                                                                                                                                                                                                 PEPR_Descricao  PEP ...
que sustenta a toda a rua que da acesso ao posto de saúde do centro da cidade\n\nfoi completamente destruída impedindo assim a passagem de carros, a Escolas João Benedito\n\nFernandes teve danos significativos em suas estruturas e em todo o material didático e permanente nela encontrado e somados a  perca de banco de dados de matriculas, cerca de 40 casa foram comprometidas com paredes telhados e estrutura\n\ndanificadas, sendo que algumas foram completamente destruídas,  deixando pessoas desalojadas, a pavimentação foi comprometida em vários locais assim como o deslizamento de massa de terra foi intenso como pode ser visto no relatório\n\nfotográfico e nas fotos em anexo, pontes e quase todas as estradas que dão acesso ao município foram afetadas algumas estão intransitáveis.                          7                        30         3.315927e+06                        1.0                         0         1.087189e+06                         1.0                          0          90599.103795                             0                            0                     0.0                           0                          0              0.000000                            8.0                           0.0             7.791523e+06              1.228524e+07  comprometimento no abastecimento de água da população, o que afetou diretamente cerca de 4.000 pessoas residentes na área urbana ocasionada por rompimento de tubulação e contaminação com esgotos danificados, o abastecimento ficou suspenso por prazo indeterminado.                   NaN                 NaN                   NaN                    NaN                            NaN                                                                                                                                            Diante deste evento adverso, houve danos no sistema de esgotamento sanitário, bueiros,\n\nencostas, vias de drenagens pluviais, alagamentos e vários pontos da cidade,  danos a pavimentação de ruas destruição de estradas vicinais na zona rural, sistema de abastecimento de\n\nágua comprometido,  prejuízos em escolas, o cais foi completamente comprometido sendo que cerca de 80% da sua estrutura desabou sobre o rio preto, a quantidade de lama nas ruas foi acima da media registrada em outros eventos, foi organizada\n\numa junta de trabalho  para retirar todo entulho e lama arrastados pela enxurrada, que deve durar cerca de 2 meses até a conclusão dos serviços.                  90599.103795                45299.551897                    3.823282e+06                  217437.849107                        0.0                        0.0                         0.0                    4.167559e+06                            0.0                          0.0      90599.103795        8.434777e+06  Os prejuízos da agricultura estão ligados aos danos causados pelas fortes chuvas, em virtude dos danos causados nas\n\nestradas vicinais que dão acesso a sede do município impossibilitando assim o escoamento de\n\ntoda a produção comprometendo boa parte dos serviços, principalmente da cultura da banana maior fonte de riqueza do Município e pro se tratar de um produto altamente perecível causando grandes prejuízos financeiros.      ...

# %%
df_eventos.dtypes.reset_index().rename(columns={0: '.dtype', 'index': 'Variável'})
# Out:
#                           Variável   .dtype
# 0                   Protocolo_S2iD   object
# 1                   Nome_Municipio   object
# 2                         Sigla_UF   object
# 3                           regiao   object
# 4                    Data_Registro   object
# 5                      Data_Evento   object
# 6                      codigo_ibge    int64
# 7              Setores Censitários   object
# 8                           Status   object
# 9                     DH_Descricao   object
# 10                       DH_MORTOS    int64
# 11                      DH_FERIDOS    int64
# 12                     DH_ENFERMOS    int64
# 13                 DH_DESABRIGADOS    int64
# 14                  DH_DESALOJADOS    int64
# 15                DH_DESAPARECIDOS    int64
# 16              DH_OUTROS AFETADOS    int64
# 17          DH_total_danos_humanos    int64
# 18                    DM_Descricao   object
# 19       DM_Uni Habita Danificadas    int64
# 20        DM_Uni Habita Destruidas    int64
# 21             DM_Uni Habita Valor  float64
# 22       DM_Inst Saúde Danificadas  float64
# 23        DM_Inst Saúde Destruidas    int64
# 24             DM_Inst Saúde Valor  float64
# 25      DM_Inst Ensino Danificadas  float64
# 26       DM_Inst Ensino Destruidas    int64
# 27            DM_Inst Ensino Valor  float64
# 28    DM_Inst Serviços Danificadas    int64
# 29     DM_Inst Serviços Destruidas    int64
# 30          DM_Inst Serviços Valor  float64
# 31      DM_Inst Comuni Danificadas    int64
# 32       DM_Inst Comuni Destruidas    int64
# 33            DM_Inst Comuni Valor  float64
# 34   DM_Obras de Infra Danificadas  float64
# 35    DM_Obras de Infra Destruidas  float64
# 36         DM_Obras de Infra Valor  float64
# 37        DM_total_danos_materiais  float64
# 38                    DA_Descricao   object
# 39           DA_Polui/cont da água   object
# 40             DA_Polui/cont do ar   object
# 41           DA_Polui/cont do solo   object
# 42          DA_Dimi/exauri hídrico   object
# 43  DA_Incêndi parques/APA's/APP's   object
# 44                  PEPL_Descricao   object
# 45    PEPL_Assis_méd e emergên(R$)  float64
# 46      PEPL_Abast de água pot(R$)  float64
# 47  PEPL_sist de esgotos sanit(R$)  float64
# 48   PEPL_Sis limp e rec lixo (R$)  float64
# 49       PEPL_Sis cont pragas (R$)  float64
# 50       PEPL_distrib energia (R$)  float64
# 51      PEPL_Telecomunicações (R$)  float64
# 52  PEPL_Tran loc/reg/l_curso (R$)  float64
# 53   PEPL_Distrib combustíveis(R$)  float64
# 54     PEPL_Segurança pública (R$)  float64
# 55                PEPL_Ensino (R$)  float64
# 56              PEPL_total_publico  float64
# 57                  PEPR_Descricao   object
# 58           PEPR_Agricultura (R$)  float64
# 59              PEPR_Pecuária (R$)  float64
# 60             PEPR_Indústria (R$)  float64
# 61              PEPR_Comércio (R$)  float64
# 62              PEPR_Serviços (R$)  float64
# 63              PEPR_total_privado  float64
# 64                        PE_PLePR  float64
# 65                       Empenhado  float64
# 66                    DensidadePop  float64
# 67                             Hab  float64
# 68                            Area  float64
# 69                             Ano  float64
# 70                             PIB  float64
# 71                       Categoria   object
# 72                           Grupo   object
# 73                        Subgrupo   object
# 74                            Tipo   object
# 75                         Subtipo   object
# 76                         COBRADE    int64

# %%
#Verificar se há protocolos duplicados

df_eventos["Protocolo_S2iD"].duplicated().sum()

#Não há protocolos duplicados
# Out:
# 0

# %%
# Excluir variáveis que não serão adicionadas ao modelo

df_eventos = df_eventos.drop(
    ['Protocolo_S2iD', 'Nome_Municipio', 'Sigla_UF', 'regiao', 'Data_Registro', 'Data_Evento', 'codigo_ibge',
     'Setores Censitários', 'COBRADE', "Ano"], axis=1)

# %%
df_na_counts = df_eventos.isna().sum().reset_index().rename(columns={0: 'Qtde. dados ausentes', 'index': 'Variável'})
df_na_counts['% de dados ausentes'] = (df_na_counts['Qtde. dados ausentes'] / len(df_eventos)) * 100
df_na_counts = df_na_counts.sort_values(by='% de dados ausentes', ascending=False)
df_na_counts
# Out:
#                           Variável  Qtde. dados ausentes  % de dados ausentes
# 32             DA_Polui/cont do ar                 18213            99.275046
# 33           DA_Polui/cont do solo                 17991            98.064973
# 31           DA_Polui/cont da água                 17371            94.685490
# 35  DA_Incêndi parques/APA's/APP's                 17009            92.712308
# 34          DA_Dimi/exauri hídrico                 16668            90.853592
# 57                       Empenhado                 14472            78.883680
# 66                         Subtipo                 13031            71.029107
# 10                    DM_Descricao                  6451            35.162978
# 61                             PIB                  5815            31.696283
# 30                    DA_Descricao                  4234            23.078600
# 36                  PEPL_Descricao                  2645            14.417312
# 49                  PEPR_Descricao                  2281            12.433228
# 65                            Tipo                  2224            12.122534
# 1                     DH_Descricao                  1222             6.660853
# 64                        Subgrupo                    30             0.163523
# 45   PEPL_Distrib combustíveis(R$)                     0             0.000000
# 48              PEPL_total_publico                     0             0.000000
# 47                PEPL_Ensino (R$)                     0             0.000000
# 46     PEPL_Segurança pública (R$)                     0             0.000000
# 7                 DH_DESAPARECIDOS                     0             0.000000
# 44  PEPL_Tran loc/reg/l_curso (R$)                     0             0.000000
# 50           PEPR_Agricultura (R$)                     0             0.000000
# 42       PEPL_distrib energia (R$)                     0             0.000000
# 41       PEPL_Sis cont pragas (R$)                     0             0.000000
# 43      PEPL_Telecomunicações (R$)                     0             0.000000
# 52             PEPR_Indústria (R$)                     0             0.000000
# 51              PEPR_Pecuária (R$)                     0             0.000000
# 39  PEPL_sist de esgotos sanit(R$)                     0             0.000000
# 53              PEPR_Comércio (R$)                     0             0.000000
# 54              PEPR_Serviços (R$)                     0             0.000000
# 55              PEPR_total_privado                     0             0.000000
# 56                        PE_PLePR                     0             0.000000
# 2                        DH_MORTOS                     0             0.000000
# 58                    DensidadePop                     0             0.000000
# 59                             Hab                     0             0.000000
# 60                            Area                     0             0.000000
# 62                       Categoria                     0             0.000000
# 63                           Grupo                     0             0.000000
# 40   PEPL_Sis limp e rec lixo (R$)                     0             0.000000
# 37    PEPL_Assis_méd e emergên(R$)                     0             0.000000
# 38      PEPL_Abast de água pot(R$)                     0             0.000000
# 21     DM_Inst Serviços Destruidas                     0             0.000000
# 9           DH_total_danos_humanos                     0             0.000000
# 11       DM_Uni Habita Danificadas                     0             0.000000
# 12        DM_Uni Habita Destruidas                     0             0.000000
# 13             DM_Uni Habita Valor                     0             0.000000
# 14       DM_Inst Saúde Danificadas                     0             0.000000
# 15        DM_Inst Saúde Destruidas                     0             0.000000
# 16             DM_Inst Saúde Valor                     0             0.000000
# 17      DM_Inst Ensino Danificadas                     0             0.000000
# 18       DM_Inst Ensino Destruidas                     0             0.000000
# 19            DM_Inst Ensino Valor                     0             0.000000
# 20    DM_Inst Serviços Danificadas                     0             0.000000
# 22          DM_Inst Serviços Valor                     0             0.000000
# 8               DH_OUTROS AFETADOS                     0             0.000000
# 23      DM_Inst Comuni Danificadas                     0             0.000000
# 24       DM_Inst Comuni Destruidas                     0             0.000000
# 25            DM_Inst Comuni Valor                     0             0.000000
# 26   DM_Obras de Infra Danificadas                     0             0.000000
# 27    DM_Obras de Infra Destruidas                     0             0.000000
# 28         DM_Obras de Infra Valor                     0             0.000000
# 29        DM_total_danos_materiais                     0             0.000000
# 6                   DH_DESALOJADOS                     0             0.000000
# 5                  DH_DESABRIGADOS                     0             0.000000
# 4                      DH_ENFERMOS                     0             0.000000
# 3                       DH_FERIDOS                     0             0.000000
# 0                           Status                     0             0.000000

# %%
#Excluir colunas que tenham mais do que 5% de dados ausentes
colunas_mantidas = df_na_counts[df_na_counts['% de dados ausentes'] < 5]['Variável']
df_eventos = df_eventos[colunas_mantidas]
print(df_eventos.columns)
# Out:
# Index(['Subgrupo', 'PEPL_Distrib combustíveis(R$)', 'PEPL_total_publico',
#        'PEPL_Ensino (R$)', 'PEPL_Segurança pública (R$)', 'DH_DESAPARECIDOS',
#        'PEPL_Tran loc/reg/l_curso (R$)', 'PEPR_Agricultura (R$)',
#        'PEPL_distrib energia (R$)', 'PEPL_Sis cont pragas (R$)',
#        'PEPL_Telecomunicações (R$)', 'PEPR_Indústria (R$)',
#        'PEPR_Pecuária (R$)', 'PEPL_sist de esgotos sanit(R$)',
#        'PEPR_Comércio (R$)', 'PEPR_Serviços (R$)', 'PEPR_total_privado',
#        'PE_PLePR', 'DH_MORTOS', 'DensidadePop', 'Hab', 'Area', 'Categoria',
#        'Grupo', 'PEPL_Sis limp e rec lixo (R$)',
#        'PEPL_Assis_méd e emergên(R$)', 'PEPL_Abast de água pot(R$)',
#        'DM_Inst Serviços Destruidas', 'DH_total_danos_humanos',
#        'DM_Uni Habita Danificadas', 'DM_Uni Habita Destruidas',
#        'DM_Uni Habita Valor', 'DM_Inst Saúde Danificadas',
#        'DM_Inst Saúde Destruidas', 'DM_Inst Saúde Valor',
#        'DM_Inst Ensino Danificadas', 'DM_Inst Ensino Destruidas',
#        'DM_Inst Ensino Valor', 'DM_Inst Serviços Danificadas',
#        'DM_Inst Serviços Valor', 'DH_OUTROS AFETADOS',
#        'DM_Inst Comuni Danificadas', 'DM_Inst Comuni Destruidas',
#        'DM_Inst Comuni Valor', 'DM_Obras de Infra Danificadas',
#        'DM_Obras de Infra Destruidas', 'DM_Obras de Infra Valor',
#        'DM_total_danos_materiais', 'DH_DESALOJADOS', 'DH_DESABRIGADOS',
#        'DH_ENFERMOS', 'DH_FERIDOS', 'Status'],
#       dtype='object')

# %%
df_eventos = pd.get_dummies(df_eventos, columns=['Subgrupo', 'Categoria', 'Grupo'], drop_first=False)
df_eventos.head(3)
# Out:
#    PEPL_Distrib combustíveis(R$)  PEPL_total_publico  PEPL_Ensino (R$)  PEPL_Segurança pública (R$)  DH_DESAPARECIDOS  PEPL_Tran loc/reg/l_curso (R$)  PEPR_Agricultura (R$)  PEPL_distrib energia (R$)  PEPL_Sis cont pragas (R$)  PEPL_Telecomunicações (R$)  PEPR_Indústria (R$)  PEPR_Pecuária (R$)  PEPL_sist de esgotos sanit(R$)  PEPR_Comércio (R$)  PEPR_Serviços (R$)  PEPR_total_privado      PE_PLePR  DH_MORTOS  DensidadePop      Hab      Area  PEPL_Sis limp e rec lixo (R$)  PEPL_Assis_méd e emergên(R$)  PEPL_Abast de água pot(R$)  DM_Inst Serviços Destruidas  DH_total_danos_humanos  DM_Uni Habita Danificadas  DM_Uni Habita Destruidas  DM_Uni Habita Valor  DM_Inst Saúde Danificadas  DM_Inst Saúde Destruidas  DM_Inst Saúde Valor  DM_Inst Ensino Danificadas  DM_Inst Ensino Destruidas  DM_Inst Ensino Valor  DM_Inst Serviços Danificadas  DM_Inst Serviços Valor  DH_OUTROS AFETADOS  DM_Inst Comuni Danificadas  DM_In