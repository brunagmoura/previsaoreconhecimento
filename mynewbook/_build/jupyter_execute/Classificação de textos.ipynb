# %% [markdown]
# ## Classificação de textos

# %% [markdown]
# ### Bibliotecas

# %%
#Bibliotecas
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import warnings

#Estilizar conteúdo
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def estilo_tabelas(df, max_altura='300px', casas_decimais=3):
    return (
        df.style.set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},  # Azul abaixo do nome das colunas
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '100px')]},
                {'selector': 'tr:nth-child(even)', 'props': [('background-color', '#f9f9f9')]},  # Fundo alternado
                {'selector': 'tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},  # Bordas cinza escuro
            ]
        ).set_properties(
            **{'background-color': '#f4f4f4', 'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        ).set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'  
        ).format(
            precision=casas_decimais  
        )
    )

# %% [markdown]
# ### Base de dados

# %%
object_columns = ['Protocolo_S2iD', 'Nome_Municipio', 'Sigla_UF', 'regiao',
                  'Setores Censitários', 'Status', 'DH_Descricao', 'DM_Descricao',
                  'DA_Descricao', 'DA_Polui/cont da água', 'DA_Polui/cont do ar',
                  'DA_Polui/cont do solo', 'DA_Dimi/exauri hídrico',
                  "DA_Incêndi parques/APA's/APP's", 'PEPL_Descricao', 'PEPR_Descricao',
                  'Categoria', 'Grupo', 'Subgrupo', 'Tipo', 'Subtipo']

dtype = {col: 'object' for col in object_columns}

df_eventos = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_desastres_rec_nrec.csv",
    sep=';',
    dtype = dtype,
    decimal=',',
)

estilo_tabelas(df_eventos.head(5))
# Out:
# <style type="text/css">
# #T_c95d4 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_c95d4 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_c95d4 tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# #T_c95d4 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_c95d4 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_c95d4 td {
#   border: 1px solid #666;
# }
# #T_c95d4  th {
#   border: 1px solid #666;
# }
# #T_c95d4_row0_col0, #T_c95d4_row0_col1, #T_c95d4_row0_col2, #T_c95d4_row0_col3, #T_c95d4_row0_col4, #T_c95d4_row0_col5, #T_c95d4_row0_col6, #T_c95d4_row0_col7, #T_c95d4_row0_col8, #T_c95d4_row0_col9, #T_c95d4_row0_col10, #T_c95d4_row0_col11, #T_c95d4_row0_col12, #T_c95d4_row0_col13, #T_c95d4_row0_col14, #T_c95d4_row0_col15, #T_c95d4_row0_col16, #T_c95d4_row0_col17, #T_c95d4_row0_col18, #T_c95d4_row0_col19, #T_c95d4_row0_col20, #T_c95d4_row0_col21, #T_c95d4_row0_col22, #T_c95d4_row0_col23, #T_c95d4_row0_col24, #T_c95d4_row0_col25, #T_c95d4_row0_col26, #T_c95d4_row0_col27, #T_c95d4_row0_col28, #T_c95d4_row0_col29, #T_c95d4_row0_col30, #T_c95d4_row0_col31, #T_c95d4_row0_col32, #T_c95d4_row0_col33, #T_c95d4_row0_col34, #T_c95d4_row0_col35, #T_c95d4_row0_col36, #T_c95d4_row0_col37, #T_c95d4_row0_col38, #T_c95d4_row0_col39, #T_c95d4_row0_col40, #T_c95d4_row0_col41, #T_c95d4_row0_col42, #T_c95d4_row0_col43, #T_c95d4_row0_col44, #T_c95d4_row0_col45, #T_c95d4_row0_col46, #T_c95d4_row0_col47, #T_c95d4_row0_col48, #T_c95d4_row0_col49, #T_c95d4_row0_col50, #T_c95d4_row0_col51, #T_c95d4_row0_col52, #T_c95d4_row0_col53, #T_c95d4_row0_col54, #T_c95d4_row0_col55, #T_c95d4_row0_col56, #T_c95d4_row0_col57, #T_c95d4_row0_col58, #T_c95d4_row0_col59, #T_c95d4_row0_col60, #T_c95d4_row0_col61, #T_c95d4_row0_col62, #T_c95d4_row0_col63, #T_c95d4_row0_col64, #T_c95d4_row0_col65, #T_c95d4_row0_col66, #T_c95d4_row0_col67, #T_c95d4_row0_col68, #T_c95d4_row0_col69, #T_c95d4_row0_col70, #T_c95d4_row0_col71, #T_c95d4_row0_col72, #T_c95d4_row0_col73, #T_c95d4_row0_col74, #T_c95d4_row0_col75, #T_c95d4_row0_col76, #T_c95d4_row0_col77, #T_c95d4_row0_col78, #T_c95d4_row0_col79, #T_c95d4_row0_col80, #T_c95d4_row0_col81, #T_c95d4_row0_col82, #T_c95d4_row0_col83, #T_c95d4_row1_col0, #T_c95d4_row1_col1, #T_c95d4_row1_col2, #T_c95d4_row1_col3, #T_c95d4_row1_col4, #T_c95d4_row1_col5, #T_c95d4_row1_col6, #T_c95d4_row1_col7, #T_c95d4_row1_col8, #T_c95d4_row1_col9, #T_c95d4_row1_col10, #T_c95d4_row1_col11, #T_c95d4_row1_col12, #T_c95d4_row1_col13, #T_c95d4_row1_col14, #T_c95d4_row1_col15, #T_c95d4_row1_col16, #T_c95d4_row1_col17, #T_c95d4_row1_col18, #T_c95d4_row1_col19, #T_c95d4_row1_col20, #T_c95d4_row1_col21, #T_c95d4_row1_col22, #T_c95d4_row1_col23, #T_c95d4_row1_col24, #T_c95d4_row1_col25, #T_c95d4_row1_col26, #T_c95d4_row1_col27, #T_c95d4_row1_col28, #T_c95d4_row1_col29, #T_c95d4_row1_col30, #T_c95d4_row1_col31, #T_c95d4_row1_col32, #T_c95d4_row1_col33, #T_c95d4_row1_col34, #T_c95d4_row1_col35, #T_c95d4_row1_col36, #T_c95d4_row1_col37, #T_c95d4_row1_col38, #T_c95d4_row1_col39, #T_c95d4_row1_col40, #T_c95d4_row1_col41, #T_c95d4_row1_col42, #T_c95d4_row1_col43, #T_c95d4_row1_col44, #T_c95d4_row1_col45, #T_c95d4_row1_col46, #T_c95d4_row1_col47, #T_c95d4_row1_col48, #T_c95d4_row1_col49, #T_c95d4_row1_col50, #T_c95d4_row1_col51, #T_c95d4_row1_col52, #T_c95d4_row1_col53, #T_c95d4_row1_col54, #T_c95d4_row1_col55, #T_c95d4_row1_col56, #T_c95d4_row1_col57, #T_c95d4_row1_col58, #T_c95d4_row1_col59, #T_c95d4_row1_col60, #T_c95d4_row1_col61, #T_c95d4_row1_col62, #T_c95d4_row1_col63, #T_c95d4_row1_col64, #T_c95d4_row1_col65, #T_c95d4_row1_col66, #T_c95d4_row1_col67, #T_c95d4_row1_col68, #T_c95d4_row1_col69, #T_c95d4_row1_col70, #T_c95d4_row1_col71, #T_c95d4_row1_col72, #T_c95d4_row1_col73, #T_c95d4_row1_col74, #T_c95d4_row1_col75, #T_c95d4_row1_col76, #T_c95d4_row1_col77, #T_c95d4_row1_col78, #T_c95d4_row1_col79, #T_c95d4_row1_col80, #T_c95d4_row1_col81, #T_c95d4_row1_col82, #T_c95d4_row1_col83, #T_c95d4_row2_col0, #T_c95d4_row2_col1, #T_c95d4_row2_col2, #T_c95d4_row2_col3, #T_c95d4_row2_col4, #T_c95d4_row2_col5, #T_c95d4_row2_col6, #T_c95d4_row2_col7, #T_c95d4_row2_col8, #T_c95d4_row2_col9, #T_c95d4_row2_col10, #T_c95d4_row2_col11, #T_c95d4_row2_col12, #T_c95d4_row2_col13, #T_c95d4_row2_col14, #T_c95d4_row2_col15, #T_c95d4_row2_col16, #T_c95d4_row2_col17, #T_c95d4_row2_col18, #T_c95d4_row2_col19, #T_c95d4_row2_col20, #T_c95d4_row2_col21, #T_c95d4_row2_col22, #T_c95d4_row2_col23 ...

# %%
df_eventos['Status'] = df_eventos['Status'].map({'Reconhecido': 0, 'Não reconhecido': 1})

# %%
df_eventos = df_eventos[["Status", "DH_Descricao", "DM_Descricao", "DA_Descricao"]]

# %%
df_DH_Descricao = df_eventos[['Status', 'DH_Descricao']].dropna(subset=['Status', 'DH_Descricao'])

# %%
df_DM_Descricao = df_eventos[['Status', 'DM_Descricao']].dropna(subset=['Status', 'DM_Descricao'])

# %%
df_DA_Descricao = df_eventos[['Status', 'DA_Descricao']].dropna(subset=['Status', 'DA_Descricao'])

# %% [markdown]
# ## Modelo para "Descrição de danos humanos"

# %%
X_train_humanos, X_test_humanos, y_train_humanos, y_test_humanos = train_test_split(df_DH_Descricao['DH_Descricao'], df_DH_Descricao['Status'], test_size=0.2, random_state=42, stratify=df_DH_Descricao['Status'])

# %%
X_train_humanos[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 X_train_humanos[0]
#
# File ~/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 0

# %%
print('TREINO : ',y_train_humanos.shape,'\n', y_train_humanos.value_counts(normalize=True),'\n')
print('TESTE  : ',y_test_humanos.shape,'\n', y_test_humanos.value_counts(normalize=True))
# Out:
# TREINO :  (13699,)
#  Status
# 0    0.912548
# 1    0.087452
# Name: proportion, dtype: float64
#
# TESTE  :  (3425,)
#  Status
# 0    0.912701
# 1    0.087299
# Name: proportion, dtype: float64

# %%
# instancia o transform CountVectorizer
tfidf_vectorizer_humanos = TfidfVectorizer()
# # tokeniza e cria o vocabulário
tfidf_vectorizer_humanos.fit(X_train_humanos)
# # mostra o vocabulário criado
print('Vocabulário: ')
print(tfidf_vectorizer_humanos.vocabulary_)
# Out:
# Vocabulário:
# {'devido': 11239, 'ao': 5571, 'desastre': 10771, 'de': 10366, 'inundação': 15955, 'ocorrida': 19303, 'no': 19002, 'município': 18668, 'faria': 13385, 'lemos': 16950, 'em': 12049, '20': 1169, '02': 53, '2021': 1208, 'foram': 13821, 'contabilizados': 9543, 'número': 19174, '23': 1390, 'pessoas': 20482, 'desabrigadas': 10698, 'que': 21936, 'tiveram': 25318, 'deixar': 10488, 'suas': 24476, 'residências': 22803, 'aumento': 6403, 'abrupto': 4222, 'do': 11611, 'rio': 23069, 'carangola': 7969, 'são': 24794, 'mateus': 17873, 'sendo': 23841, 'levadas': 16986, 'para': 19783, 'abrigos': 4210, 'disponibilizados': 11467, 'pela': 20163, 'prefeitura': 21235, '_x000d_': 4075, '06': 136, 'alojadas': 5137, 'centro': 8411, 'cultural': 10134, 'fica': 13596, 'na': 18771, 'rua': 23252, 'josé': 16532, 'dittz': 11545, 'sn': 24214, 'ponto': 20918, 'referência': 22435, 'parque': 19913, 'exposição': 13208, '13': 572, 'escola': 12593, 'municipal': 18654, 'diogo': 11390, 'vasconcelos': 26278, 'coronel': 9796, 'joão': 16541, 'marcelino': 17699, '112': 372, '04': 97, 'quadra': 21876, 'poliesportiva': 20863, 'bairro': 6610, '37': 2126, 'desalojadas': 10730, 'cheia': 8544, 'dos': 11710, 'respectivas': 22835, 'casas': 8156, 'tendo': 25105, 'todos': 25355, 'eles': 11968, 'encaminhado': 12173, 'familiares': 13360, 'amigos': 5339, 'aproximadamente': 5707, '500': 2667, 'alguma': 5062, 'forma': 13832, 'atingidas': 6263, 'pelo': 20176, 'evento': 13042, 'população': 20943, 'modo': 18329, 'geral': 14360, 'vem': 26333, 'afetada': 4666, 'estiagem': 12856, 'perímetro': 20441, 'urbano': 26046, 'com': 8956, 'racionamento': 22077, 'água': 26971, 'interior': 15851, 'transporte': 25622, 'potável': 21086, '76': 3456, 'famílias': 13376, 'agricultura': 4819, 'prejuízos': 21274, 'econômicos': 11844, 'afetadas': 4670, 'diretamente': 11413, 'todas': 25349, 'as': 6030, 'da': 10253, 'area': 5831, 'urbana': 26038, 'rural': 23288, 'necessitando': 18871, 'auxilio': 6458, 'sua': 24474, 'subsistencia': 24539, 'adverso': 4617, 'havido': 14810, 'ernestina': 12510, 'atingiu': 6280, 'toda': 25346, 'área': 26986, 'está': 12970, 'acarretando': 4279, 'dificuldade': 11320, 'locomoção': 17201, 'das': 10344, 'escoamento': 12587, 'produção': 21510, 'vista': 26622, 'condições': 9267, 'trafegabilidade': 25520, 'assim': 6089, 'como': 9025, 'ir': 16047, 'vir': 26572, 'maquinários': 17663, 'agrícolas': 4864, 'buscavam': 7413, 'atendimentos': 6221, 'diversos': 11555, 'cidade': 8624, 'problemas': 21447, 'saúde': 23630, 'estudantes': 12960, 'ainda': 4907, 'importante': 15289, 'enfatizar': 12277, 'aulas': 6388, 'rede': 22365, 'pública': 21869, 'ensino': 12345, 'suspensas': 24755, 'por': 20950, 'dois': 11640, 'dias': 11293, 'os': 19563, '08': 177, '09': 194, 'junho': 16578, 'corrente': 9822, 'ano': 5491, 'causou': 8281, 'um': 25967, 'transtorno': 25627, 'abalo': 4104, 'normalidade': 19039, 'destaca': 11085, 'se': 23664, 'não': 19162, 'dispõe': 11488, 'saneamento': 23508, 'básico': 7430, 'suficiente': 24593, 'comprometendo': 9126, 'parte': 19919, 'águas': 26974, 'pluviais': 20778, 'ademais': 4508, 'estação': 12830, 'captação': 7925, 'tratamento': 25657, 'distribuição': 11522, 'companhia': 9038, 'esgoto': 12640, 'estado': 12798, 'amapá': 5256, 'caesa': 7535, 'localizada': 17177, 'às': 26968, 'margens': 17730, 'calçoene': 7664, 'foi': 13791, 'sinistrada': 24128, 'tanto': 24930, 'alagamento': 4947, 'quanto': 21914, 'interrompendo': 15882, 'fornecimento': 13878, 'tratada': 25653, 'atendida': 6213, 'serviço': 23973, 'consequências': 9401, 'desses': 11082, 'eventos': 13044, 'impactaram': 15239, 'doenças': 11638, 'diarreicas': 11289, 'viróticas': 26598, 'dermatológicas': 10657, 'relacionadas': 22550, 'qualidade': 21890, 'principalmente': 21415, 'crianças': 9997, 'idosos': 15120, 'acordo': 4434, 'constante': 9459, 'parecer': 19876, 'técnico': 25900, 'nº08': 19150, 'cedec': 8353, '2719': 1633, '2538': 1530, '181': 1006, 'perfazendo': 20312, 'total': 25455, '497': 2646, 'direta': 11411, 'indiretamente': 15500, 'pelas': 2 ...

# %%
pipeline_humanos = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1,2))),
    ('clf', SGDClassifier(loss='log_loss')),
])

classificador_humanos = pipeline_humanos.fit(X_train_humanos, y_train_humanos)

 predicted_humanos = classificador_humanos.predict(X_test_humanos)

# %%
print(metrics.classification_report(y_test_humanos, predicted_humanos))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      3126
#            1       1.00      0.01      0.01       299
#
#     accuracy                           0.91      3425
#    macro avg       0.96      0.50      0.48      3425
# weighted avg       0.92      0.91      0.87      3425

# %% [markdown]
# ### Modelo para descrição de danos materiais

# %%
X_train_materiais, X_test_materiais, y_train_materiais, y_test_materiais = train_test_split(df_DM_Descricao['DM_Descricao'], df_DM_Descricao['Status'], test_size=0.2, random_state=42, stratify=df_DM_Descricao['Status'])

# %%
X_train_materiais[0]
# Out:
# 'Os danos são representados pelas avarias/destruições acentuadas resultantes nas estradas/pontes vicinais do município, em virtude das enxurradas, que resultaram na erosão/deslocamento acentuado do saibro alocado nas estradas, bem como em sérios danos aos sistemas de drenagens/pontes de madeira/concreto, em que algumas foram arrancadas em sua totalidade, além da queda de barreiras e do estreitamento das pistas de rolamento das estradas vicinais, devido ao avanço do leito do rio.\n\nAdemais, houve danos às residências localizadas no entorno do rio, bem como à unidade de saúde/escola/galpão comunitário da Comunidade do Rio Novo, principalmente devido à interrupção do acesso e dos serviços ofertados.'

# %%
print('TREINO : ',y_train_materiais.shape,'\n', y_train_materiais.value_counts(normalize=True),'\n')
print('TESTE  : ',y_test_materiais.shape,'\n', y_test_materiais.value_counts(normalize=True))
# Out:
# TREINO :  (9516,)
#  Status
# 0    0.897226
# 1    0.102774
# Name: proportion, dtype: float64
#
# TESTE  :  (2379,)
#  Status
# 0    0.897436
# 1    0.102564
# Name: proportion, dtype: float64

# %%
# instancia o transform CountVectorizer
tfidf_vectorizer_materiais = TfidfVectorizer()
# # tokeniza e cria o vocabulário
tfidf_vectorizer_materiais.fit(X_train_materiais)
# # mostra o vocabulário criado
print('Vocabulário: ')
print(tfidf_vectorizer_materiais.vocabulary_)
# Out:
# Vocabulário:
# {'no': 18632, 'bairro': 5037, 'pirulito': 20431, 'nas': 18376, 'ruas': 22982, 'pedro': 19895, 'ii': 14273, 'rua': 22976, 'beira': 5365, 'rio': 22715, 'uma': 25862, 'casa': 6951, 'destruída': 9987, 'parcialmente': 19585, 'danificada': 9207, 'paredes': 19601, 'com': 7920, 'avarias': 4895, 'duas': 10563, 'casas': 6963, 'enxurradas': 11327, 'inundações': 14974, 'que': 21589, 'entraram': 11268, 'água': 27049, 'dentro': 9495, 'danificando': 9218, 'bens': 5453, 'materiais': 17326, 'parte': 19636, 'da': 9137, 'bela': 5377, 'vista': 26615, 'telhado': 24894, 'destruído': 9991, 'deslizamento': 9793, 'de': 9299, 'massa': 17292, 'quintal': 21677, 'outra': 19263, 'centro': 7305, 'um': 25860, 'muro': 18236, 'desabou': 9592, 'na': 18328, 'salvador': 23186, 'outro': 19266, 'residência': 22465, 'duque': 10584, 'caxias': 7145, 'branca': 5897, 'jk': 15564, 'manoel': 16998, 'vital': 26638, 'palmeiras': 19410, 'belarmino': 5379, 'dias': 10136, 'oito': 19019, 'por': 20728, 'motivo': 18069, 'inundação': 14971, 'destruiu': 9978, 'calçada': 6402, 'totalmente': 25358, 'deixando': 9394, 'em': 10931, 'risco': 22733, 'qualquer': 21538, 'momento': 17908, 'desabar': 9582, 'os': 19213, 'seus': 23804, 'como': 7973, 'colchoes': 7844, 'outros': 19268, 'domicílios': 10449, 'suas': 24323, 'residências': 22467, 'as': 4527, 'comércios': 8150, 'não': 18810, 'ficaram': 12486, 'impunes': 14455, 'citado': 7649, 'anteriormente': 3971, 'cerca': 7324, '570': 1793, 'edificações': 10692, 'foram': 12728, 'atingidas': 4721, 'sendo': 23649, 'totalmente_x000d_': 25359, 'destruídas': 9989, 'onde': 19078, 'conseguimos': 8309, 'registrar': 22201, 'imagens': 14312, 'pois': 20611, 'levadas': 16240, 'pela': 19926, 'força': 12812, 'das': 9273, 'águas': 27053, 'estas': 11707, 'ribeirinhas': 22675, 'ao': 4016, 'taquari': 24779, 'edificadas': 10687, 'todas': 25221, 'madeira': 16777, 'munícipes': 18220, 'baixa': 5042, 'renda': 22337, 'custo': 9075, 'aproximado': 4164, '10': 233, '000': 1, '00': 0, 'cada': 6218, 'edificação': 10690, 'além': 3671, 'destas': 9924, 'demais': 9438, 'danificadas': 9209, 'médio': 18301, 'valor': 26121, 'este': 11715, 'necessário': 18473, 'para': 19478, 'reconstrução': 22013, 'muros': 18238, 'contenção': 8499, 'encostas': 11147, 'substituição': 24379, 'esquadrias': 11632, 'vidros': 26481, 'cercas': 7331, 'pisos': 20446, 'pintura': 20367, 'parcial': 19581, 'ou': 19251, 'até': 4796, 'mesmo': 17582, 'reforço': 22171, 'estrutural': 11853, 'alguns': 3505, 'casos': 6993, 'salientamos': 23154, 'tal': 24685, 'se': 23444, 'fará': 12280, 'deixar': 9395, 'condições': 8232, 'habitáveis': 13860, 'quais': 21532, 'geram': 13325, 'montante': 17945, '870': 2383, '00_x000d_': 35, 'dois': 10433, 'milhões': 17684, 'oitocentos': 19022, 'setenta': 23789, 'mil': 17663, 'reais': 21861, '_x000d_': 2636, 'instalações': 14775, 'públicas': 21509, 'uso': 26011, 'comunitário': 8144, 'são': 24593, 'salão': 23198, 'marques': 17224, 'do': 10407, 'herval': 13967, 'picão': 20277, 'toda': 25220, 'estrutura': 11846, 'veio': 26263, 'abaixo': 2657, 'festas': 12459, 'bar': 5146, 'armazém': 4379, 'cancha': 6571, 'bocha': 5693, 'família': 12240, 'bronca': 6007, 'obras': 18848, 'infraestrutura': 14684, 'pública': 21506, 'encosta': 11144, 'detonação': 10058, 'pavimentação': 19820, 'general_x000d_': 13263, 'osório': 19232, 'estrada': 11800, 'barão': 5259, 'branco': 5900, 'aterro': 4699, 'avenida': 4907, 'general': 13262, 'daltro': 9181, 'filho': 12518, 'passeio_x000d_': 19701, 'público_x000d_': 21512, 'recuperação': 22061, 'asfalto': 4549, 'ers': 11414, '129': 417, 'lateral': 16074, 'em_x000d_': 10933, 'concreto': 8200, 'cabeceira': 6160, 'ponte': 20685, 'sobre': 24053, 'arroio': 4472, 'conventos_x000d_': 8590, 'vermelho': 26374, 'padre': 19330, 'fernando': 12419, 'steffens': 24286, 'leopoldo': 16216, 'marder_x000d_': 17130, 'construção': 8425, 'galeria': 13109, '470': 1574, 'metros': 17610, 'vermelhos': 26376, 'lindeiro': 16357, 'antigo': 3982, 'moinho': 17867, 'cruzeiro': 8944, 'sul': 24443, 'prédio_x000d_ ...

# %%
pipeline_materiais = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1,2))),
    ('clf', SGDClassifier(loss='log_loss')),
])

classificador_materiais = pipeline_materiais.fit(X_train_materiais, y_train_materiais)

predicted_materiais = classificador_materiais.predict(X_test_materiais)

# %%
print(metrics.classification_report(y_test_materiais, predicted_materiais))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      2135
#            1       0.00      0.00      0.00       244
#
#     accuracy                           0.90      2379
#    macro avg       0.45      0.50      0.47      2379
# weighted avg       0.81      0.90      0.85      2379

# %% [markdown]
# #### Modelo para descrição de danos ambientais

# %%
X_train_ambiental, X_test_ambiental, y_train_ambiental, y_test_ambiental = train_test_split(df_DA_Descricao['DA_Descricao'], df_DA_Descricao['Status'], test_size=0.2, random_state=42, stratify=df_DA_Descricao['Status'])

# %%
X_train_ambiental[13282]
# Out:
# 'Não há registros de danos ambientais.'

# %%
print('TREINO : ',y_train_ambiental.shape,'\n', y_train_materiais.value_counts(normalize=True),'\n')
print('TESTE  : ',y_test_ambiental.shape,'\n', y_test_materiais.value_counts(normalize=True))

# %%
# instancia o transform CountVectorizer
tfidf_vectorizer_materiais = TfidfVectorizer()
# # tokeniza e cria o vocabulário
tfidf_vectorizer_materiais.fit(X_train_materiais)
# # mostra o vocabulário criado
print('Vocabulário: ')
print(tfidf_vectorizer_materiais.vocabulary_)

# %%
pipeline_materiais = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1,2))),
    ('clf', SGDClassifier(loss='log_loss')),
])

classificador_materiais = pipeline_materiais.fit(X_train_materiais, y_train_materiais)

predicted_materiais = classificador_materiais.predict(X_test_materiais)

# %%
print(metrics.classification_report(y_test_materiais, predicted_materiais))
