# %% [markdown]
# ## Análise preliminar

# %% [markdown]
# ### Bibliotecas

# %%
#Bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import warnings

#Estilizar conteúdo
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def estilo_tabelas(df, max_altura='300px', casas_decimais=2):
    return (
        df.style.set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '100px')]},
                {'selector': 'tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},
            ]
        ).set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        ).set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'  
        ).format(
            precision=casas_decimais  
        )
    )

# %% [markdown]
# ### Base de dados
#
# A base de dados dessa análise preliminar contém todos os dados descritos na "introdução" deste documento.

# %%
object_columns = ['Protocolo_S2iD', 'Nome_Municipio', 'Sigla_UF', 'regiao',
                  'Setores Censitários', 'Status', 'DH_Descricao', 'DM_Descricao',
                  'DA_Descricao', 'DA_Polui/cont da água', 'DA_Polui/cont do ar',
                  'DA_Polui/cont do solo', 'DA_Dimi/exauri hídrico',
                  "DA_Incêndi parques/APA's/APP's", 'PEPL_Descricao', 'PEPR_Descricao',
                  'Categoria', 'Grupo', 'Subgrupo', 'Tipo', 'Subtipo']

dtype = {col: 'object' for col in object_columns}

df_eventos = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_desastres_rec_nrec.csv",
    sep=';',
    dtype = dtype,
    decimal=',',
)

estilo_tabelas(df_eventos.head(5))
# Out:
# <style type="text/css">
# #T_9eb2f thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_9eb2f td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_9eb2f tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_9eb2f table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_9eb2f td {
#   border: 1px solid #666;
# }
# #T_9eb2f  th {
#   border: 1px solid #666;
# }
# #T_9eb2f_row0_col0, #T_9eb2f_row0_col1, #T_9eb2f_row0_col2, #T_9eb2f_row0_col3, #T_9eb2f_row0_col4, #T_9eb2f_row0_col5, #T_9eb2f_row0_col6, #T_9eb2f_row0_col7, #T_9eb2f_row0_col8, #T_9eb2f_row0_col9, #T_9eb2f_row0_col10, #T_9eb2f_row0_col11, #T_9eb2f_row0_col12, #T_9eb2f_row0_col13, #T_9eb2f_row0_col14, #T_9eb2f_row0_col15, #T_9eb2f_row0_col16, #T_9eb2f_row0_col17, #T_9eb2f_row0_col18, #T_9eb2f_row0_col19, #T_9eb2f_row0_col20, #T_9eb2f_row0_col21, #T_9eb2f_row0_col22, #T_9eb2f_row0_col23, #T_9eb2f_row0_col24, #T_9eb2f_row0_col25, #T_9eb2f_row0_col26, #T_9eb2f_row0_col27, #T_9eb2f_row0_col28, #T_9eb2f_row0_col29, #T_9eb2f_row0_col30, #T_9eb2f_row0_col31, #T_9eb2f_row0_col32, #T_9eb2f_row0_col33, #T_9eb2f_row0_col34, #T_9eb2f_row0_col35, #T_9eb2f_row0_col36, #T_9eb2f_row0_col37, #T_9eb2f_row0_col38, #T_9eb2f_row0_col39, #T_9eb2f_row0_col40, #T_9eb2f_row0_col41, #T_9eb2f_row0_col42, #T_9eb2f_row0_col43, #T_9eb2f_row0_col44, #T_9eb2f_row0_col45, #T_9eb2f_row0_col46, #T_9eb2f_row0_col47, #T_9eb2f_row0_col48, #T_9eb2f_row0_col49, #T_9eb2f_row0_col50, #T_9eb2f_row0_col51, #T_9eb2f_row0_col52, #T_9eb2f_row0_col53, #T_9eb2f_row0_col54, #T_9eb2f_row0_col55, #T_9eb2f_row0_col56, #T_9eb2f_row0_col57, #T_9eb2f_row0_col58, #T_9eb2f_row0_col59, #T_9eb2f_row0_col60, #T_9eb2f_row0_col61, #T_9eb2f_row0_col62, #T_9eb2f_row0_col63, #T_9eb2f_row0_col64, #T_9eb2f_row0_col65, #T_9eb2f_row0_col66, #T_9eb2f_row0_col67, #T_9eb2f_row0_col68, #T_9eb2f_row0_col69, #T_9eb2f_row0_col70, #T_9eb2f_row0_col71, #T_9eb2f_row0_col72, #T_9eb2f_row0_col73, #T_9eb2f_row0_col74, #T_9eb2f_row0_col75, #T_9eb2f_row0_col76, #T_9eb2f_row0_col77, #T_9eb2f_row0_col78, #T_9eb2f_row0_col79, #T_9eb2f_row0_col80, #T_9eb2f_row0_col81, #T_9eb2f_row0_col82, #T_9eb2f_row0_col83, #T_9eb2f_row1_col0, #T_9eb2f_row1_col1, #T_9eb2f_row1_col2, #T_9eb2f_row1_col3, #T_9eb2f_row1_col4, #T_9eb2f_row1_col5, #T_9eb2f_row1_col6, #T_9eb2f_row1_col7, #T_9eb2f_row1_col8, #T_9eb2f_row1_col9, #T_9eb2f_row1_col10, #T_9eb2f_row1_col11, #T_9eb2f_row1_col12, #T_9eb2f_row1_col13, #T_9eb2f_row1_col14, #T_9eb2f_row1_col15, #T_9eb2f_row1_col16, #T_9eb2f_row1_col17, #T_9eb2f_row1_col18, #T_9eb2f_row1_col19, #T_9eb2f_row1_col20, #T_9eb2f_row1_col21, #T_9eb2f_row1_col22, #T_9eb2f_row1_col23, #T_9eb2f_row1_col24, #T_9eb2f_row1_col25, #T_9eb2f_row1_col26, #T_9eb2f_row1_col27, #T_9eb2f_row1_col28, #T_9eb2f_row1_col29, #T_9eb2f_row1_col30, #T_9eb2f_row1_col31, #T_9eb2f_row1_col32, #T_9eb2f_row1_col33, #T_9eb2f_row1_col34, #T_9eb2f_row1_col35, #T_9eb2f_row1_col36, #T_9eb2f_row1_col37, #T_9eb2f_row1_col38, #T_9eb2f_row1_col39, #T_9eb2f_row1_col40, #T_9eb2f_row1_col41, #T_9eb2f_row1_col42, #T_9eb2f_row1_col43, #T_9eb2f_row1_col44, #T_9eb2f_row1_col45, #T_9eb2f_row1_col46, #T_9eb2f_row1_col47, #T_9eb2f_row1_col48, #T_9eb2f_row1_col49, #T_9eb2f_row1_col50, #T_9eb2f_row1_col51, #T_9eb2f_row1_col52, #T_9eb2f_row1_col53, #T_9eb2f_row1_col54, #T_9eb2f_row1_col55, #T_9eb2f_row1_col56, #T_9eb2f_row1_col57, #T_9eb2f_row1_col58, #T_9eb2f_row1_col59, #T_9eb2f_row1_col60, #T_9eb2f_row1_col61, #T_9eb2f_row1_col62, #T_9eb2f_row1_col63, #T_9eb2f_row1_col64, #T_9eb2f_row1_col65, #T_9eb2f_row1_col66, #T_9eb2f_row1_col67, #T_9eb2f_row1_col68, #T_9eb2f_row1_col69, #T_9eb2f_row1_col70, #T_9eb2f_row1_col71, #T_9eb2f_row1_col72, #T_9eb2f_row1_col73, #T_9eb2f_row1_col74, #T_9eb2f_row1_col75, #T_9eb2f_row1_col76, #T_9eb2f_row1_col77, #T_9eb2f_row1_col78, #T_9eb2f_row1_col79, #T_9eb2f_row1_col80, #T_9eb2f_row1_col81, #T_9eb2f_row1_col82, #T_9eb2f_row1_col83, #T_9eb2f_row2_col0, #T_9eb2f_row2_col1, #T_9eb2f_row2_col2, #T_9eb2f_row2_col3, #T_9eb2f_row2_col4, #T_9eb2f_row2_col5, #T_9eb2f_row2_col6, #T_9eb2f_row2_col7, #T_9eb2f_row2_col8, #T_9eb2f_row2_col9, #T_9eb2f_row2_col10, #T_9eb2f_row2_col11, #T_9eb2f_row2_col12, #T_9eb2f_row2_col13, #T_9eb2f_row2_col14, #T_9eb2f_row2_col15, #T_9eb2f_row2_col16, #T_9eb2f_row2_col17, #T_9eb2f_row2_col18, #T_9eb2f_row2_col19, #T_9eb2f_row2_col20, #T_9eb2f_row2_col21, #T_9eb2f_row2_col22, #T_9eb2f_row2_col23 ...

# %% [markdown]
# ### Tipo de variável

# %%
df_eventos_tipo = df_eventos.dtypes.reset_index().rename(columns={0: 'Tipo', 'index': 'Variável'})
estilo_tabelas(df_eventos_tipo)
# Out:
# <style type="text/css">
# #T_8afa4 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_8afa4 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_8afa4 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_8afa4 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_8afa4 td {
#   border: 1px solid #666;
# }
# #T_8afa4  th {
#   border: 1px solid #666;
# }
# #T_8afa4_row0_col0, #T_8afa4_row0_col1, #T_8afa4_row1_col0, #T_8afa4_row1_col1, #T_8afa4_row2_col0, #T_8afa4_row2_col1, #T_8afa4_row3_col0, #T_8afa4_row3_col1, #T_8afa4_row4_col0, #T_8afa4_row4_col1, #T_8afa4_row5_col0, #T_8afa4_row5_col1, #T_8afa4_row6_col0, #T_8afa4_row6_col1, #T_8afa4_row7_col0, #T_8afa4_row7_col1, #T_8afa4_row8_col0, #T_8afa4_row8_col1, #T_8afa4_row9_col0, #T_8afa4_row9_col1, #T_8afa4_row10_col0, #T_8afa4_row10_col1, #T_8afa4_row11_col0, #T_8afa4_row11_col1, #T_8afa4_row12_col0, #T_8afa4_row12_col1, #T_8afa4_row13_col0, #T_8afa4_row13_col1, #T_8afa4_row14_col0, #T_8afa4_row14_col1, #T_8afa4_row15_col0, #T_8afa4_row15_col1, #T_8afa4_row16_col0, #T_8afa4_row16_col1, #T_8afa4_row17_col0, #T_8afa4_row17_col1, #T_8afa4_row18_col0, #T_8afa4_row18_col1, #T_8afa4_row19_col0, #T_8afa4_row19_col1, #T_8afa4_row20_col0, #T_8afa4_row20_col1, #T_8afa4_row21_col0, #T_8afa4_row21_col1, #T_8afa4_row22_col0, #T_8afa4_row22_col1, #T_8afa4_row23_col0, #T_8afa4_row23_col1, #T_8afa4_row24_col0, #T_8afa4_row24_col1, #T_8afa4_row25_col0, #T_8afa4_row25_col1, #T_8afa4_row26_col0, #T_8afa4_row26_col1, #T_8afa4_row27_col0, #T_8afa4_row27_col1, #T_8afa4_row28_col0, #T_8afa4_row28_col1, #T_8afa4_row29_col0, #T_8afa4_row29_col1, #T_8afa4_row30_col0, #T_8afa4_row30_col1, #T_8afa4_row31_col0, #T_8afa4_row31_col1, #T_8afa4_row32_col0, #T_8afa4_row32_col1, #T_8afa4_row33_col0, #T_8afa4_row33_col1, #T_8afa4_row34_col0, #T_8afa4_row34_col1, #T_8afa4_row35_col0, #T_8afa4_row35_col1, #T_8afa4_row36_col0, #T_8afa4_row36_col1, #T_8afa4_row37_col0, #T_8afa4_row37_col1, #T_8afa4_row38_col0, #T_8afa4_row38_col1, #T_8afa4_row39_col0, #T_8afa4_row39_col1, #T_8afa4_row40_col0, #T_8afa4_row40_col1, #T_8afa4_row41_col0, #T_8afa4_row41_col1, #T_8afa4_row42_col0, #T_8afa4_row42_col1, #T_8afa4_row43_col0, #T_8afa4_row43_col1, #T_8afa4_row44_col0, #T_8afa4_row44_col1, #T_8afa4_row45_col0, #T_8afa4_row45_col1, #T_8afa4_row46_col0, #T_8afa4_row46_col1, #T_8afa4_row47_col0, #T_8afa4_row47_col1, #T_8afa4_row48_col0, #T_8afa4_row48_col1, #T_8afa4_row49_col0, #T_8afa4_row49_col1, #T_8afa4_row50_col0, #T_8afa4_row50_col1, #T_8afa4_row51_col0, #T_8afa4_row51_col1, #T_8afa4_row52_col0, #T_8afa4_row52_col1, #T_8afa4_row53_col0, #T_8afa4_row53_col1, #T_8afa4_row54_col0, #T_8afa4_row54_col1, #T_8afa4_row55_col0, #T_8afa4_row55_col1, #T_8afa4_row56_col0, #T_8afa4_row56_col1, #T_8afa4_row57_col0, #T_8afa4_row57_col1, #T_8afa4_row58_col0, #T_8afa4_row58_col1, #T_8afa4_row59_col0, #T_8afa4_row59_col1, #T_8afa4_row60_col0, #T_8afa4_row60_col1, #T_8afa4_row61_col0, #T_8afa4_row61_col1, #T_8afa4_row62_col0, #T_8afa4_row62_col1, #T_8afa4_row63_col0, #T_8afa4_row63_col1, #T_8afa4_row64_col0, #T_8afa4_row64_col1, #T_8afa4_row65_col0, #T_8afa4_row65_col1, #T_8afa4_row66_col0, #T_8afa4_row66_col1, #T_8afa4_row67_col0, #T_8afa4_row67_col1, #T_8afa4_row68_col0, #T_8afa4_row68_col1, #T_8afa4_row69_col0, #T_8afa4_row69_col1, #T_8afa4_row70_col0, #T_8afa4_row70_col1, #T_8afa4_row71_col0, #T_8afa4_row71_col1, #T_8afa4_row72_col0, #T_8afa4_row72_col1, #T_8afa4_row73_col0, #T_8afa4_row73_col1, #T_8afa4_row74_col0, #T_8afa4_row74_col1, #T_8afa4_row75_col0, #T_8afa4_row75_col1, #T_8afa4_row76_col0, #T_8afa4_row76_col1, #T_8afa4_row77_col0, #T_8afa4_row77_col1, #T_8afa4_row78_col0, #T_8afa4_row78_col1, #T_8afa4_row79_col0, #T_8afa4_row79_col1, #T_8afa4_row80_col0, #T_8afa4_row80_col1, #T_8afa4_row81_col0, #T_8afa4_row81_col1, #T_8afa4_row82_col0, #T_8afa4_row82_col1, #T_8afa4_row83_col0, #T_8afa4_row83_col1 {
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_8afa4" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8afa4_level0_col0" class="col_heading level0 col0" >Variável</th>
#       <th id="T_8afa4_level0_col1" class="col_heading level0 col1" >Tipo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8afa4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8afa4_row0_col0" class="data row0 col0" >Protocolo_S2iD</td>
#       <td id="T_8afa4_row0_col1" class="data row0 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8afa4_row1_col0" class="data row1 col0" >Nome_Municipio</td>
#       <td id="T_8afa4_row1_col1" class="data row1 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8afa4_row2_col0" class="data row2 col0" >Sigla_UF</td>
#       <td id="T_8afa4_row2_col1" class="data row2 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8afa4_row3_col0" class="data row3 col0" >regiao</td>
#       <td id="T_8afa4_row3_col1" class="data row3 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8afa4_row4_col0" class="data row4 col0" >Data_Registro</td>
#       <td id="T_8afa4_row4_col1" class="data row4 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8afa4_row5_col0" class="data row5 col0" >Data_Evento</td>
#       <td id="T_8afa4_row5_col1" class="data row5 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8afa4_row6_col0" class="data row6 col0" >codigo_ibge</td>
#       <td id="T_8afa4_row6_col1" class="data row6 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8afa4_row7_col0" class="data row7 col0" >Setores Censitários</td>
#       <td id="T_8afa4_row7_col1" class="data row7 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8afa4_row8_col0" class="data row8 col0" >Status</td>
#       <td id="T_8afa4_row8_col1" class="data row8 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8afa4_row9_col0" class="data row9 col0" >DH_Descricao</td>
#       <td id="T_8afa4_row9_col1" class="data row9 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8afa4_row10_col0" class="data row10 col0" >DH_MORTOS</td>
#       <td id="T_8afa4_row10_col1" class="data row10 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8afa4_row11_col0" class="data row11 col0" >DH_FERIDOS</td>
#       <td id="T_8afa4_row11_col1" class="data row11 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8afa4_row12_col0" class="data row12 col0" >DH_ENFERMOS</td>
#       <td id="T_8afa4_row12_col1" class="data row12 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8afa4_row13_col0" class="data row13 col0" >DH_DESABRIGADOS</td>
#       <td id="T_8afa4_row13_col1" class="data row13 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_8afa4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8afa4_row14_col0" class="data row14 col0" >DH_DESALOJADOS</td>
#       <td id="

# %% [markdown]
# ### Estatísticas descritivas

# %%
estilo_tabelas(df_eventos.describe())
# Out:
# <style type="text/css">
# #T_5b7be thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_5b7be td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_5b7be tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_5b7be table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_5b7be td {
#   border: 1px solid #666;
# }
# #T_5b7be  th {
#   border: 1px solid #666;
# }
# #T_5b7be_row0_col0, #T_5b7be_row0_col1, #T_5b7be_row0_col2, #T_5b7be_row0_col3, #T_5b7be_row0_col4, #T_5b7be_row0_col5, #T_5b7be_row0_col6, #T_5b7be_row0_col7, #T_5b7be_row0_col8, #T_5b7be_row0_col9, #T_5b7be_row0_col10, #T_5b7be_row0_col11, #T_5b7be_row0_col12, #T_5b7be_row0_col13, #T_5b7be_row0_col14, #T_5b7be_row0_col15, #T_5b7be_row0_col16, #T_5b7be_row0_col17, #T_5b7be_row0_col18, #T_5b7be_row0_col19, #T_5b7be_row0_col20, #T_5b7be_row0_col21, #T_5b7be_row0_col22, #T_5b7be_row0_col23, #T_5b7be_row0_col24, #T_5b7be_row0_col25, #T_5b7be_row0_col26, #T_5b7be_row0_col27, #T_5b7be_row0_col28, #T_5b7be_row0_col29, #T_5b7be_row0_col30, #T_5b7be_row0_col31, #T_5b7be_row0_col32, #T_5b7be_row0_col33, #T_5b7be_row0_col34, #T_5b7be_row0_col35, #T_5b7be_row0_col36, #T_5b7be_row0_col37, #T_5b7be_row0_col38, #T_5b7be_row0_col39, #T_5b7be_row0_col40, #T_5b7be_row0_col41, #T_5b7be_row0_col42, #T_5b7be_row0_col43, #T_5b7be_row0_col44, #T_5b7be_row0_col45, #T_5b7be_row0_col46, #T_5b7be_row0_col47, #T_5b7be_row0_col48, #T_5b7be_row0_col49, #T_5b7be_row0_col50, #T_5b7be_row0_col51, #T_5b7be_row0_col52, #T_5b7be_row0_col53, #T_5b7be_row0_col54, #T_5b7be_row0_col55, #T_5b7be_row0_col56, #T_5b7be_row0_col57, #T_5b7be_row0_col58, #T_5b7be_row0_col59, #T_5b7be_row1_col0, #T_5b7be_row1_col1, #T_5b7be_row1_col2, #T_5b7be_row1_col3, #T_5b7be_row1_col4, #T_5b7be_row1_col5, #T_5b7be_row1_col6, #T_5b7be_row1_col7, #T_5b7be_row1_col8, #T_5b7be_row1_col9, #T_5b7be_row1_col10, #T_5b7be_row1_col11, #T_5b7be_row1_col12, #T_5b7be_row1_col13, #T_5b7be_row1_col14, #T_5b7be_row1_col15, #T_5b7be_row1_col16, #T_5b7be_row1_col17, #T_5b7be_row1_col18, #T_5b7be_row1_col19, #T_5b7be_row1_col20, #T_5b7be_row1_col21, #T_5b7be_row1_col22, #T_5b7be_row1_col23, #T_5b7be_row1_col24, #T_5b7be_row1_col25, #T_5b7be_row1_col26, #T_5b7be_row1_col27, #T_5b7be_row1_col28, #T_5b7be_row1_col29, #T_5b7be_row1_col30, #T_5b7be_row1_col31, #T_5b7be_row1_col32, #T_5b7be_row1_col33, #T_5b7be_row1_col34, #T_5b7be_row1_col35, #T_5b7be_row1_col36, #T_5b7be_row1_col37, #T_5b7be_row1_col38, #T_5b7be_row1_col39, #T_5b7be_row1_col40, #T_5b7be_row1_col41, #T_5b7be_row1_col42, #T_5b7be_row1_col43, #T_5b7be_row1_col44, #T_5b7be_row1_col45, #T_5b7be_row1_col46, #T_5b7be_row1_col47, #T_5b7be_row1_col48, #T_5b7be_row1_col49, #T_5b7be_row1_col50, #T_5b7be_row1_col51, #T_5b7be_row1_col52, #T_5b7be_row1_col53, #T_5b7be_row1_col54, #T_5b7be_row1_col55, #T_5b7be_row1_col56, #T_5b7be_row1_col57, #T_5b7be_row1_col58, #T_5b7be_row1_col59, #T_5b7be_row2_col0, #T_5b7be_row2_col1, #T_5b7be_row2_col2, #T_5b7be_row2_col3, #T_5b7be_row2_col4, #T_5b7be_row2_col5, #T_5b7be_row2_col6, #T_5b7be_row2_col7, #T_5b7be_row2_col8, #T_5b7be_row2_col9, #T_5b7be_row2_col10, #T_5b7be_row2_col11, #T_5b7be_row2_col12, #T_5b7be_row2_col13, #T_5b7be_row2_col14, #T_5b7be_row2_col15, #T_5b7be_row2_col16, #T_5b7be_row2_col17, #T_5b7be_row2_col18, #T_5b7be_row2_col19, #T_5b7be_row2_col20, #T_5b7be_row2_col21, #T_5b7be_row2_col22, #T_5b7be_row2_col23, #T_5b7be_row2_col24, #T_5b7be_row2_col25, #T_5b7be_row2_col26, #T_5b7be_row2_col27, #T_5b7be_row2_col28, #T_5b7be_row2_col29, #T_5b7be_row2_col30, #T_5b7be_row2_col31, #T_5b7be_row2_col32, #T_5b7be_row2_col33, #T_5b7be_row2_col34, #T_5b7be_row2_col35, #T_5b7be_row2_col36, #T_5b7be_row2_col37, #T_5b7be_row2_col38, #T_5b7be_row2_col39, #T_5b7be_row2_col40, #T_5b7be_row2_col41, #T_5b7be_row2_col42, #T_5b7be_row2_col43, #T_5b7be_row2_col44, #T_5b7be_row2_col45, #T_5b7be_row2_col46, #T_5b7be_row2_col47, #T_5b7be_row2_col48, #T_5b7be_row2_col49, #T_5b7be_row2_col50, #T_5b7be_row2_col51, #T_5b7be_row2_col52, #T_5b7be_row2_col53, #T_5b7be_row2_col54, #T_5b7be_row2_col55, #T_5b7be_row2_col56, #T_5b7be_row2_col57, #T_5b7be_row2_col58, #T_5b7be_row2_col59, #T_5b7be_row3_col0, #T_5b7be_row3_col1, #T_5b7be_row3_col2, #T_5b7be_row3_col3, #T_5b7be_row3_col4, #T_5b7be_row3_col5, #T_5b7be_row3_col6, #T_5b7be_row3_col7, #T_5b7be_row3_col8, #T_5b7be_row3_col9, #T_5b7be_row3_col10, #T_5b7be_row3_col11, #T_5b7be ...

# %% [markdown]
# ### Registros

# %% [markdown]
# Protocolos duplicados: não foram localizados protocolos duplicados

# %%
df_eventos["Protocolo_S2iD"].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Protocolos por ano:

# %%
# Dados agrupados por ano
df_eventos_temporal = df_eventos.groupby('Ano_Evento').agg({
    'DH_total_danos_humanos': 'sum',
    'DM_total_danos_materiais': 'sum',
    'PE_PLePR': 'sum',
    'Protocolo_S2iD': 'count'  # Contagem de ocorrências de Protocolo_S2_iD
}).reset_index()

def formatar_milhar(x, pos):
    return '%1.0fK' % (x * 1e-3)

def formatar_milhao(x, pos):
    return '%1.0fM' % (x * 1e-6)

# Criação da figura com três subplots lado a lado
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Gráfico 1: Danos Humanos
ax1 = axs[0]
ax2 = ax1.twinx()  # Eixo y secundário

ax1.plot(df_eventos_temporal['Ano_Evento'], df_eventos_temporal['DH_total_danos_humanos'], color='red', label='Danos Humanos', marker='o')
ax2.bar(df_eventos_temporal['Ano_Evento'], df_eventos_temporal['Protocolo_S2iD'], color='lightgrey', label='Desastres registrados', alpha=0.6)

ax1.set_xlabel('Ano')
ax1.set_ylabel('Danos Humanos', color='red')
ax2.set_ylabel(' ', color='grey')

ax1.set_title('Danos Humanos (2010 - 2024)')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

ax1.yaxis.set_major_formatter(FuncFormatter(formatar_milhar))

# Gráfico 2: Danos Materiais
ax3 = axs[1]
ax4 = ax3.twinx()  # Eixo y secundário

ax3.plot(df_eventos_temporal['Ano_Evento'], df_eventos_temporal['DM_total_danos_materiais'], color='blue', label='Danos Materiais', marker='o')
ax4.bar(df_eventos_temporal['Ano_Evento'], df_eventos_temporal['Protocolo_S2iD'], color='lightgrey', label='Desastres registrados', alpha=0.6)

ax3.set_xlabel('Ano')
ax3.set_ylabel('Danos Materiais', color='blue')
ax4.set_ylabel(' ', color='grey')

ax3.set_title('Danos Materiais (2010-2024)')
ax3.legend(loc='upper left')
ax4.legend(loc='upper right')

ax3.yaxis.set_major_formatter(FuncFormatter(formatar_milhao))

# Gráfico 3: PE PLePR
ax5 = axs[2]
ax6 = ax5.twinx()  # Eixo y secundário

ax5.plot(df_eventos_temporal['Ano_Evento'], df_eventos_temporal['PE_PLePR'], color='green', label='PE PLePR', marker='o')
ax6.bar(df_eventos_temporal['Ano_Evento'], df_eventos_temporal['Protocolo_S2iD'], color='lightgrey', label='Desastres registrados', alpha=0.6)

ax5.set_xlabel('Ano')
ax5.set_ylabel('Prej. econ.', color='green')
ax6.set_ylabel('Desastres registrados', color='grey')

ax5.set_title('Prejuízos econômicos (2010-2024)')
ax5.legend(loc='upper left')
ax6.legend(loc='upper right')

ax5.yaxis.set_major_formatter(FuncFormatter(formatar_milhao))

# Ajuste do layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlação entre as features

# %%
# Correlação entre as variáveis independentes

variaveisnum_todas = [
    'DH_MORTOS', 'DH_FERIDOS', 'DH_ENFERMOS', 'DH_DESABRIGADOS', 'DH_DESALOJADOS', 'DH_DESAPARECIDOS', 'DH_OUTROS AFETADOS',
    'DM_Uni Habita Danificadas', 'DM_Uni Habita Destruidas',  
    'DM_Inst Saúde Danificadas', 'DM_Inst Saúde Destruidas', 
    'DM_Inst Ensino Danificadas', 'DM_Inst Ensino Destruidas',  
    'DM_Inst Serviços Danificadas', 'DM_Inst Serviços Destruidas',  
    'DM_Inst Comuni Danificadas', 'DM_Inst Comuni Destruidas',  
    'DM_Obras de Infra Danificadas', 'DM_Obras de Infra Destruidas', 
    'PEPL_Assis_méd e emergên(R$)', 'PEPL_Abast de água pot(R$)', 'PEPL_sist de esgotos sanit(R$)', 
    'PEPL_Sis limp e rec lixo (R$)', 'PEPL_Sis cont pragas (R$)', 'PEPL_distrib energia (R$)', 
    'PEPL_Telecomunicações (R$)', 'PEPL_Tran loc/reg/l_curso (R$)', 'PEPL_Distrib combustíveis(R$)', 
    'PEPL_Segurança pública (R$)', 'PEPL_Ensino (R$)', 'PEPR_Agricultura (R$)', 
    'PEPR_Pecuária (R$)', 'PEPR_Indústria (R$)', 'PEPR_Comércio (R$)', 'PEPR_Serviços (R$)',
    'Empenhado', 'DensidadePop', 'PIB'
]

df_corr_todas = df_eventos[variaveisnum_todas]

correlacao_todas = df_corr_todas.corr()

mask = np.triu(np.ones_like(correlacao_todas, dtype=bool), k=1)

plt.figure(figsize=(12, 10))
heatmap = sns.heatmap(
    correlacao_todas, 
    cmap="Reds", 
    annot=True,
    fmt=".2f",
    linewidths=0.2, 
    linecolor='white',
    cbar_kws={"shrink": 0.8, "aspect": 40},
    square=True,
    mask=mask,
    annot_kws={"size": 6.5},
)
plt.title('Matriz de Correlação', fontsize=16, pad=20)
plt.xticks(rotation=90, fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.tight_layout()
plt.show()

# %%
variaveisnum_selecionadas = [
    'DH_total_danos_humanos', 'DM_total_danos_materiais', 'PEPL_total_publico', 'PEPR_total_privado', 'Empenhado', 'DensidadePop', 'PIB'
]

df_corr_selecionadas = df_eventos[variaveisnum_selecionadas]

correlacao_selecionadas = df_corr_selecionadas.corr()

mask = np.triu(np.ones_like(correlacao_selecionadas, dtype=bool), k=1)

plt.figure(figsize=(5, 5))
heatmap = sns.heatmap(
    correlacao_selecionadas, 
    cmap="Reds", 
    annot=True,
    fmt=".2f",
    linewidths=0.2, 
    linecolor='white',
    cbar_kws={"shrink": 0.8, "aspect": 40},
    square=True,
    mask=mask,
    annot_kws={"size": 6.5},
)
plt.title('Matriz de Correlação', fontsize=10, pad=2)
plt.xticks(rotation=90, fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Balanceamento da variável 'target'
#
# Há desbalanceamento entre o status "Reconhecido" e "Não reconhecido", o qual deverá ser tratado na etapa de pré-processamento dos dados.

# %%
status_counts = df_eventos['Status'].value_counts()
print("\nDistribuição da variável 'Status':")
display(status_counts)
# Out:
# Distribuição da variável 'Status':
# Status
# Reconhecido        16483
# Não reconhecido     1863
# Name: count, dtype: int64

# %% [markdown]
# ### Dados ausentes
#
# Existem variáveis com quantidade de dados ausentes superior a 50%. Essas variáveis serão tratadas no pré-processamento.

# %%
df_na_counts = df_eventos.isna().sum().reset_index().rename(columns={0: 'Qtde. dados ausentes', 'index': 'Variável'})
df_na_counts['% de dados ausentes'] = (df_na_counts['Qtde. dados ausentes'] / len(df_eventos)) * 100
df_na_counts['Qtde. dados ausentes'] = df_na_counts['Qtde. dados ausentes'].astype(int)
df_na_counts = df_na_counts.sort_values(by='% de dados ausentes', ascending=False)
estilo_tabelas(df_na_counts)
# Out:
# <style type="text/css">
# #T_56b7c thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_56b7c td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_56b7c tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# #T_56b7c tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_56b7c table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_56b7c td {
#   border: 1px solid #666;
# }
# #T_56b7c  th {
#   border: 1px solid #666;
# }
# #T_56b7c_row0_col0, #T_56b7c_row0_col1, #T_56b7c_row0_col2, #T_56b7c_row1_col0, #T_56b7c_row1_col1, #T_56b7c_row1_col2, #T_56b7c_row2_col0, #T_56b7c_row2_col1, #T_56b7c_row2_col2, #T_56b7c_row3_col0, #T_56b7c_row3_col1, #T_56b7c_row3_col2, #T_56b7c_row4_col0, #T_56b7c_row4_col1, #T_56b7c_row4_col2, #T_56b7c_row5_col0, #T_56b7c_row5_col1, #T_56b7c_row5_col2, #T_56b7c_row6_col0, #T_56b7c_row6_col1, #T_56b7c_row6_col2, #T_56b7c_row7_col0, #T_56b7c_row7_col1, #T_56b7c_row7_col2, #T_56b7c_row8_col0, #T_56b7c_row8_col1, #T_56b7c_row8_col2, #T_56b7c_row9_col0, #T_56b7c_row9_col1, #T_56b7c_row9_col2, #T_56b7c_row10_col0, #T_56b7c_row10_col1, #T_56b7c_row10_col2, #T_56b7c_row11_col0, #T_56b7c_row11_col1, #T_56b7c_row11_col2, #T_56b7c_row12_col0, #T_56b7c_row12_col1, #T_56b7c_row12_col2, #T_56b7c_row13_col0, #T_56b7c_row13_col1, #T_56b7c_row13_col2, #T_56b7c_row14_col0, #T_56b7c_row14_col1, #T_56b7c_row14_col2, #T_56b7c_row15_col0, #T_56b7c_row15_col1, #T_56b7c_row15_col2, #T_56b7c_row16_col0, #T_56b7c_row16_col1, #T_56b7c_row16_col2, #T_56b7c_row17_col0, #T_56b7c_row17_col1, #T_56b7c_row17_col2, #T_56b7c_row18_col0, #T_56b7c_row18_col1, #T_56b7c_row18_col2, #T_56b7c_row19_col0, #T_56b7c_row19_col1, #T_56b7c_row19_col2, #T_56b7c_row20_col0, #T_56b7c_row20_col1, #T_56b7c_row20_col2, #T_56b7c_row21_col0, #T_56b7c_row21_col1, #T_56b7c_row21_col2, #T_56b7c_row22_col0, #T_56b7c_row22_col1, #T_56b7c_row22_col2, #T_56b7c_row23_col0, #T_56b7c_row23_col1, #T_56b7c_row23_col2, #T_56b7c_row24_col0, #T_56b7c_row24_col1, #T_56b7c_row24_col2, #T_56b7c_row25_col0, #T_56b7c_row25_col1, #T_56b7c_row25_col2, #T_56b7c_row26_col0, #T_56b7c_row26_col1, #T_56b7c_row26_col2, #T_56b7c_row27_col0, #T_56b7c_row27_col1, #T_56b7c_row27_col2, #T_56b7c_row28_col0, #T_56b7c_row28_col1, #T_56b7c_row28_col2, #T_56b7c_row29_col0, #T_56b7c_row29_col1, #T_56b7c_row29_col2, #T_56b7c_row30_col0, #T_56b7c_row30_col1, #T_56b7c_row30_col2, #T_56b7c_row31_col0, #T_56b7c_row31_col1, #T_56b7c_row31_col2, #T_56b7c_row32_col0, #T_56b7c_row32_col1, #T_56b7c_row32_col2, #T_56b7c_row33_col0, #T_56b7c_row33_col1, #T_56b7c_row33_col2, #T_56b7c_row34_col0, #T_56b7c_row34_col1, #T_56b7c_row34_col2, #T_56b7c_row35_col0, #T_56b7c_row35_col1, #T_56b7c_row35_col2, #T_56b7c_row36_col0, #T_56b7c_row36_col1, #T_56b7c_row36_col2, #T_56b7c_row37_col0, #T_56b7c_row37_col1, #T_56b7c_row37_col2, #T_56b7c_row38_col0, #T_56b7c_row38_col1, #T_56b7c_row38_col2, #T_56b7c_row39_col0, #T_56b7c_row39_col1, #T_56b7c_row39_col2, #T_56b7c_row40_col0, #T_56b7c_row40_col1, #T_56b7c_row40_col2, #T_56b7c_row41_col0, #T_56b7c_row41_col1, #T_56b7c_row41_col2, #T_56b7c_row42_col0, #T_56b7c_row42_col1, #T_56b7c_row42_col2, #T_56b7c_row43_col0, #T_56b7c_row43_col1, #T_56b7c_row43_col2, #T_56b7c_row44_col0, #T_56b7c_row44_col1, #T_56b7c_row44_col2, #T_56b7c_row45_col0, #T_56b7c_row45_col1, #T_56b7c_row45_col2, #T_56b7c_row46_col0, #T_56b7c_row46_col1, #T_56b7c_row46_col2, #T_56b7c_row47_col0, #T_56b7c_row47_col1, #T_56b7c_row47_col2, #T_56b7c_row48_col0, #T_56b7c_row48_col1, #T_56b7c_row48_col2, #T_56b7c_row49_col0, #T_56b7c_row49_col1, #T_56b7c_row49_col2, #T_56b7c_row50_col0, #T_56b7c_row50_col1, #T_56b7c_row50_col2, #T_56b7c_row51_col0, #T_56b7c_row51_col1, #T_56b7c_row51_col2, #T_56b7c_row52_col0, #T_56b7c_row52_col1, #T_56b7c_row52_col2, #T_56b7c_row53_col0, #T_56b7c_row53_col1, #T_56b7c_row53_col2, #T_56b7c_row54_col0, #T_56b7c_row54_col1, #T_56b7c_row54_col2, #T_56b7c_row55_col0, #T_56b7c_row55_col1, #T_56b7c_row55_col2, #T_56b7c_row56_col0, #T_56b7c_row56_col1, #T_56b7c_row56_col2, #T_56b7c_row57_col0, #T_56b7c_row57_col1, #T_56b7c_row57_col2, #T_56b7c_row58_col0, #T_56b7c_row58_col1, #T_56b7c_row58_col2, #T_56b7c_row59_col0, #T_56b7c_row59_col1, #T_56b7c_row59_col2, #T_56b7c_row60_col0, #T_56b7c_row60_col1, #T_56b7c_row60_col2, #T_56b7c_row61_col0, #T_56b7c_row61_col1, #T_56b7c_row61_col2, #T_56b7c_row62_col0, #T_56b7c_row62_col1, #T_56b7c_row62_col2, #T_56b7c_row63_col0, #T_56b7c_row63_col1, #T_56b7c_row63_col2 ...
#   background-color: #f4f4f4;
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# </style>
# <table id="T_56b7c" style="height:auto; overflow:auto; max-height:300px; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56b7c_level0_col0" class="col_heading level0 col0" >Variável</th>
#       <th id="T_56b7c_level0_col1" class="col_heading level0 col1" >Qtde. dados ausentes</th>
#       <th id="T_56b7c_level0_col2" class="col_heading level0 col2" >% de dados ausentes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56b7c_level0_row0" class="row_heading level0 row0" >40</th>
#       <td id="T_56b7c_row0_col0" class="data row0 col0" >DA_Polui/cont do ar</td>
#       <td id="T_56b7c_row0_col1" class="data row0 col1" >18213</td>
#       <td id="T_56b7c_row0_col2" class="data row0 col2" >99.275</td>
#     </tr>
#     <tr>
#       <th id="T_56b7c_level0_row1" class="row_heading level0 row1" >41</th>
#       <td id="T_56b7c_row1_col0" class="data row1 col0" >DA_Polui/cont do solo</td>
#       <td id="T_56b7c_row1_col1" class="data row1 col1" >17991</td>
#       <td id="T_56b7c_row1_col2" class="data row1 col2" >98.065</td>
#     </tr>
#     <tr>
#       <th id="T_56b7c_level0_row2" class="row_heading level0 row2" >39</th>
#       <td id="T_56b7c_row2_col0" class="data row2 col0" >DA_Polui/cont da água</td>
#       <td id="T_56b7c_row2_col1" class="data row2 col1" >17371</td>
#       <td id="T_56b7c_row2_col2" class="data row2 col2" >94.685</td>
#     </tr>
#     <tr>
#       <th id="T_56b7c_level0_row3" class="row_heading level0 row3" >43</th>
#       <td id="T_56b7c_row3_col0" class="data row3 col0" >DA_Incêndi parques/APA's/APP's</td>
#       <td id="T_56b7c_row3_col1" class="data row3 col1" >17009</td>
#       <td id="T_56b7c_row3_col2" class="data row3 col2" >92.712</td>
#     </tr>
#     <tr>
#       <th id="T_56b7c_level0_row4" class="row_heading level0 row4" >42</th>
#       <td id="T_56b7c_row4_col0" class="data row4 col0" >DA_Dimi/exauri hídrico</td>
#       <td id="T_56b7c_row4_col1" class="data row4 col1" >16668</td>
#       <td id="T_56b7c_row4_col2" class="data row4 col2" >90.854</td>
#     </tr>
#     <tr>
#       <th id="T_56b7c_level0_row5" class="row_heading level0 row5" >65</th>
#       <td id="T_56b7c_row5_col0" class="data row5 col0" >Empenhado</td>
#       <td id="T_56b7c_row5_col1" class="data row5 col1" >14472</td>
#       <td id="T_56b7c_row5_col2" class="data row5 col2" >78.884</td>
#     </tr>
#     <tr>
#       <th id="T_56b7c_level0_row6" class="row_heading level0 row6" >75</th>
#       <td id="T_56b7c_row6_col0" clas
