# %% [markdown]
# ## Modelo "base"

# %% [markdown]
# Neste teste será considerada a base de dados completa, sem considerar o pré-processamento dos dados indicado no capítulo "Pré Processamento".

# %% [markdown]
# ### Bibliotecas e bases de dados

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn import metrics
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import OneHotEncoder

#Estilizar conteúdo
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

def estilo_tabelas(df, max_altura='300px', casas_decimais=3):
    return (
        df.style.set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '100px')]},
                {'selector': 'tr:nth-child(odd)', 'props': [('background-color', '#ffffff')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},  # Bordas cinza escuro
            ]
        ).set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        ).set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'  
        ).format(
            precision=casas_decimais  
        )
    )

# Importar a base de dados

object_columns = ['Protocolo_S2iD', 'Nome_Municipio', 'Sigla_UF', 'regiao',
                  'Setores Censitários', 'Status', 'DH_Descricao', 'DM_Descricao',
                  'DA_Descricao', 'DA_Polui/cont da água', 'DA_Polui/cont do ar',
                  'DA_Polui/cont do solo', 'DA_Dimi/exauri hídrico',
                  "DA_Incêndi parques/APA's/APP's", 'PEPL_Descricao', 'PEPR_Descricao',
                  'Categoria', 'Grupo', 'Subgrupo', 'Tipo', 'Subtipo']

dtype = {col: 'object' for col in object_columns}

df_eventos = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_desastres_rec_nrec.csv",
    sep=';',
    dtype = dtype,
    decimal=',',
)

estilo_tabelas(df_eventos.head(5))
# Out:
# <style type="text/css">
# #T_06279 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_06279 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_06279 tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_06279 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_06279 td {
#   border: 1px solid #666;
# }
# #T_06279  th {
#   border: 1px solid #666;
# }
# #T_06279_row0_col0, #T_06279_row0_col1, #T_06279_row0_col2, #T_06279_row0_col3, #T_06279_row0_col4, #T_06279_row0_col5, #T_06279_row0_col6, #T_06279_row0_col7, #T_06279_row0_col8, #T_06279_row0_col9, #T_06279_row0_col10, #T_06279_row0_col11, #T_06279_row0_col12, #T_06279_row0_col13, #T_06279_row0_col14, #T_06279_row0_col15, #T_06279_row0_col16, #T_06279_row0_col17, #T_06279_row0_col18, #T_06279_row0_col19, #T_06279_row0_col20, #T_06279_row0_col21, #T_06279_row0_col22, #T_06279_row0_col23, #T_06279_row0_col24, #T_06279_row0_col25, #T_06279_row0_col26, #T_06279_row0_col27, #T_06279_row0_col28, #T_06279_row0_col29, #T_06279_row0_col30, #T_06279_row0_col31, #T_06279_row0_col32, #T_06279_row0_col33, #T_06279_row0_col34, #T_06279_row0_col35, #T_06279_row0_col36, #T_06279_row0_col37, #T_06279_row0_col38, #T_06279_row0_col39, #T_06279_row0_col40, #T_06279_row0_col41, #T_06279_row0_col42, #T_06279_row0_col43, #T_06279_row0_col44, #T_06279_row0_col45, #T_06279_row0_col46, #T_06279_row0_col47, #T_06279_row0_col48, #T_06279_row0_col49, #T_06279_row0_col50, #T_06279_row0_col51, #T_06279_row0_col52, #T_06279_row0_col53, #T_06279_row0_col54, #T_06279_row0_col55, #T_06279_row0_col56, #T_06279_row0_col57, #T_06279_row0_col58, #T_06279_row0_col59, #T_06279_row0_col60, #T_06279_row0_col61, #T_06279_row0_col62, #T_06279_row0_col63, #T_06279_row0_col64, #T_06279_row0_col65, #T_06279_row0_col66, #T_06279_row0_col67, #T_06279_row0_col68, #T_06279_row0_col69, #T_06279_row0_col70, #T_06279_row0_col71, #T_06279_row0_col72, #T_06279_row0_col73, #T_06279_row0_col74, #T_06279_row0_col75, #T_06279_row0_col76, #T_06279_row0_col77, #T_06279_row0_col78, #T_06279_row0_col79, #T_06279_row0_col80, #T_06279_row0_col81, #T_06279_row0_col82, #T_06279_row0_col83, #T_06279_row1_col0, #T_06279_row1_col1, #T_06279_row1_col2, #T_06279_row1_col3, #T_06279_row1_col4, #T_06279_row1_col5, #T_06279_row1_col6, #T_06279_row1_col7, #T_06279_row1_col8, #T_06279_row1_col9, #T_06279_row1_col10, #T_06279_row1_col11, #T_06279_row1_col12, #T_06279_row1_col13, #T_06279_row1_col14, #T_06279_row1_col15, #T_06279_row1_col16, #T_06279_row1_col17, #T_06279_row1_col18, #T_06279_row1_col19, #T_06279_row1_col20, #T_06279_row1_col21, #T_06279_row1_col22, #T_06279_row1_col23, #T_06279_row1_col24, #T_06279_row1_col25, #T_06279_row1_col26, #T_06279_row1_col27, #T_06279_row1_col28, #T_06279_row1_col29, #T_06279_row1_col30, #T_06279_row1_col31, #T_06279_row1_col32, #T_06279_row1_col33, #T_06279_row1_col34, #T_06279_row1_col35, #T_06279_row1_col36, #T_06279_row1_col37, #T_06279_row1_col38, #T_06279_row1_col39, #T_06279_row1_col40, #T_06279_row1_col41, #T_06279_row1_col42, #T_06279_row1_col43, #T_06279_row1_col44, #T_06279_row1_col45, #T_06279_row1_col46, #T_06279_row1_col47, #T_06279_row1_col48, #T_06279_row1_col49, #T_06279_row1_col50, #T_06279_row1_col51, #T_06279_row1_col52, #T_06279_row1_col53, #T_06279_row1_col54, #T_06279_row1_col55, #T_06279_row1_col56, #T_06279_row1_col57, #T_06279_row1_col58, #T_06279_row1_col59, #T_06279_row1_col60, #T_06279_row1_col61, #T_06279_row1_col62, #T_06279_row1_col63, #T_06279_row1_col64, #T_06279_row1_col65, #T_06279_row1_col66, #T_06279_row1_col67, #T_06279_row1_col68, #T_06279_row1_col69, #T_06279_row1_col70, #T_06279_row1_col71, #T_06279_row1_col72, #T_06279_row1_col73, #T_06279_row1_col74, #T_06279_row1_col75, #T_06279_row1_col76, #T_06279_row1_col77, #T_06279_row1_col78, #T_06279_row1_col79, #T_06279_row1_col80, #T_06279_row1_col81, #T_06279_row1_col82, #T_06279_row1_col83, #T_06279_row2_col0, #T_06279_row2_col1, #T_06279_row2_col2, #T_06279_row2_col3, #T_06279_row2_col4, #T_06279_row2_col5, #T_06279_row2_col6, #T_06279_row2_col7, #T_06279_row2_col8, #T_06279_row2_col9, #T_06279_row2_col10, #T_06279_row2_col11, #T_06279_row2_col12, #T_06279_row2_col13, #T_06279_row2_col14, #T_06279_row2_col15, #T_06279_row2_col16, #T_06279_row2_col17, #T_06279_row2_col18, #T_06279_row2_col19, #T_06279_row2_col20, #T_06279_row2_col21, #T_06279_row2_col22, #T_06279_row2_col23 ...

# %% [markdown]
# ### Ajustes da base de dados

# %%
# Remover colunas com mais de 50% de dados ausentes
colunas_para_remover = [
    'Protocolo_S2iD', 'Nome_Municipio', 'Sigla_UF', 'Data_Registro', 'Data_Evento', 'codigo_ibge', 
    'Setores Censitários', 'DH_Descricao', 'DM_Descricao', 'DA_Descricao', 'DA_Polui/cont da água', 
    'DA_Polui/cont do ar', 'DA_Polui/cont do solo', 'DA_Dimi/exauri hídrico', 'PEPL_Descricao', 'DA_Incêndi parques/APA\'s/APP\'s', 
    'PEPR_Descricao', 'Ano_Evento', 'Empenhado', 'Município - UF', 'Subgrupo', 'Tipo', 'Subtipo', 'COBRADE'
]

df_eventos_limpa = df_eventos.drop(columns=colunas_para_remover)

# Remover linhas com NA
df_eventos_limpa = df_eventos_limpa.dropna()

# Encoding das variáveis categóricas mantidas
categorias = ['regiao', 'Categoria', 'Grupo']
df_eventos_limpa = pd.get_dummies(df_eventos_limpa, columns=categorias, drop_first=False, dtype=int)

# Shuffle das linhas porque os eventos são registrados por sequência temporal
df_eventos_limpa = df_eventos_limpa.sample(frac=1, random_state=1).reset_index(drop=True)

# Encoding da variável target
df_eventos_limpa['Status'] = df_eventos_limpa['Status'].map({'Reconhecido': 0, 'Não reconhecido': 1})

print("Antes, a base de dados possuia a seguinte dimensão:", df_eventos.shape)
print("Após a eliminação das colunas com mais de 50% de dados ausentes e das linhas com dados ausentes, a base de dados passou a ter a seguinte dimensão:", df_eventos_limpa.shape)
estilo_tabelas(df_eventos_limpa.head(5))
# Out:
# Antes, a base de dados possuia a seguinte dimensão: (26258, 84)
# Após a eliminação das colunas com mais de 50% de dados ausentes e das linhas com dados ausentes, a base de dados passou a ter a seguinte dimensão: (5474, 73)
# <style type="text/css">
# #T_12e3e thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_12e3e td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 100px;
# }
# #T_12e3e tr:nth-child(odd) {
#   background-color: #ffffff;
# }
# #T_12e3e table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_12e3e td {
#   border: 1px solid #666;
# }
# #T_12e3e  th {
#   border: 1px solid #666;
# }
# #T_12e3e_row0_col0, #T_12e3e_row0_col1, #T_12e3e_row0_col2, #T_12e3e_row0_col3, #T_12e3e_row0_col4, #T_12e3e_row0_col5, #T_12e3e_row0_col6, #T_12e3e_row0_col7, #T_12e3e_row0_col8, #T_12e3e_row0_col9, #T_12e3e_row0_col10, #T_12e3e_row0_col11, #T_12e3e_row0_col12, #T_12e3e_row0_col13, #T_12e3e_row0_col14, #T_12e3e_row0_col15, #T_12e3e_row0_col16, #T_12e3e_row0_col17, #T_12e3e_row0_col18, #T_12e3e_row0_col19, #T_12e3e_row0_col20, #T_12e3e_row0_col21, #T_12e3e_row0_col22, #T_12e3e_row0_col23, #T_12e3e_row0_col24, #T_12e3e_row0_col25, #T_12e3e_row0_col26, #T_12e3e_row0_col27, #T_12e3e_row0_col28, #T_12e3e_row0_col29, #T_12e3e_row0_col30, #T_12e3e_row0_col31, #T_12e3e_row0_col32, #T_12e3e_row0_col33, #T_12e3e_row0_col34, #T_12e3e_row0_col35, #T_12e3e_row0_col36, #T_12e3e_row0_col37, #T_12e3e_row0_col38, #T_12e3e_row0_col39, #T_12e3e_row0_col40, #T_12e3e_row0_col41, #T_12e3e_row0_col42, #T_12e3e_row0_col43, #T_12e3e_row0_col44, #T_12e3e_row0_col45, #T_12e3e_row0_col46, #T_12e3e_row0_col47, #T_12e3e_row0_col48, #T_12e3e_row0_col49, #T_12e3e_row0_col50, #T_12e3e_row0_col51, #T_12e3e_row0_col52, #T_12e3e_row0_col53, #T_12e3e_row0_col54, #T_12e3e_row0_col55, #T_12e3e_row0_col56, #T_12e3e_row0_col57, #T_12e3e_row0_col58, #T_12e3e_row0_col59, #T_12e3e_row0_col60, #T_12e3e_row0_col61, #T_12e3e_row0_col62, #T_12e3e_row0_col63, #T_12e3e_row0_col64, #T_12e3e_row0_col65, #T_12e3e_row0_col66, #T_12e3e_row0_col67, #T_12e3e_row0_col68, #T_12e3e_row0_col69, #T_12e3e_row0_col70, #T_12e3e_row0_col71, #T_12e3e_row0_col72, #T_12e3e_row1_col0, #T_12e3e_row1_col1, #T_12e3e_row1_col2, #T_12e3e_row1_col3, #T_12e3e_row1_col4, #T_12e3e_row1_col5, #T_12e3e_row1_col6, #T_12e3e_row1_col7, #T_12e3e_row1_col8, #T_12e3e_row1_col9, #T_12e
Status'].value_counts()
print("\nBalanceamento da variável 'Status':")
display(status_counts)
# Out:
# Distribuição da variável 'Status':
# Status
# 0    4998
# 1     476
# Name: count, dtype: int64

# %% [markdown]
# ### Modelo sem balanceamento

# %% [markdown]
# #### Treino e teste

# %%
X = df_eventos_limpa.drop('Status', axis=1)

y = df_eventos_limpa['Status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %% [markdown]
# #### Treinamento sem balanceamento

# %%
# Criar pipeline com normalização e modelo de Regressão Logística
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(random_state=1, solver='lbfgs'))
])

# Definir hiperparâmetros para o Grid Search
param_grid = {
    'logreg__C': [0.01, 0.1, 1, 10],  
    'logreg__max_iter': [1000],  
    'logreg__fit_intercept': [True, False],  
    'logreg__tol': [1e-4, 1e-3],  # Tolerância para convergência
    'logreg__penalty': ['l1', 'l2'],  # Tipos de penalidade
}

# Grid Search com validação cruzada
grid_search = GridSearchCV(pipeline, param_grid, cv=3, scoring='f1_weighted', n_jobs=-1)
1
grid_search.fit(X_train, y_train)

# Melhor modelo encontrado
logreg_best = grid_search.best_estimator_

print(f"Melhores hiperparâmetros: {grid_search.best_params_}")

y_pred = logreg_best.predict(X_test)

# Classification report

classification_report = metrics.classification_report(y_test, y_pred, digits=6, target_names=['Reconhecido', 'Não reconhecido'])
print('Classification report para modelo "base" (sem balanceamento): \n')
print(classification_report)
# Out:
# Melhores hiperparâmetros: {'logreg__C': 10, 'logreg__fit_intercept': True, 'logreg__max_iter': 1000, 'logreg__penalty': 'l2', 'logreg__tol': 0.001}
# Classification report para modelo "base" (sem balanceamento):
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.923507  0.990000  0.955598      1000
# Não reconhecido   0.565217  0.136842  0.220339        95
#
#        accuracy                       0.915982      1095
#       macro avg   0.744362  0.563421  0.587969      1095
#    weighted avg   0.892423  0.915982  0.891809      1095

# %%
ConfusionMatrixDisplay.from_estimator(grid_search, X_test, y_test, 
                                      values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])

# %% [markdown]
# ### Moelo com balanceamento SMOTE

# %% [markdown]
# #### Treino e teste

# %%
X_smote = df_eventos_limpa.drop('Status', axis=1)

y_smote = df_eventos_limpa['Status']

X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_smote, y_smote, test_size=0.2, random_state=1, stratify=y)

# %% [markdown]
# #### Treinamento com balanceamento SMOTE

# %%
smote = SMOTE(random_state=1)
X_train_smote, y_train_smote = smote.fit_resample(X_train_smote, y_train_smote)

pipeline_smote = Pipeline([
    ('scaler', StandardScaler()), 
    ('logreg', LogisticRegression(random_state=1, solver='lbfgs'))  
])

# Definir hiperparâmetros para o Grid Search
param_grid_smote = {
    'logreg__C': [0.01, 0.1, 1, 10],  
    'logreg__max_iter': [1000],  
    'logreg__fit_intercept': [True, False],
    'logreg__tol': [1e-4, 1e-3],
    'logreg__penalty': ['l1', 'l2'],
}

# Grid Search com validação cruzada
grid_search_smote = GridSearchCV(pipeline_smote, param_grid_smote, cv=3, scoring='f1_weighted', n_jobs=-1)

# Treinar o pipeline com Grid Search
grid_search_smote.fit(X_train_smote, y_train_smote)

# Melhor modelo encontrado
logreg_best_smote = grid_search_smote.best_estimator_

print(f"Melhores hiperparâmetros: {grid_search_smote.best_params_}")

# Classification report
y_pred_smote = logreg_best_smote.predict(X_test_smote)

classification_report_smote = metrics.classification_report(y_test_smote, y_pred_smote, digits=6, target_names=['Reconhecido', 'Não reconhecido'])
print('Classification report para modelo base com balanceamento smote: \n')
print(classification_report_smote)
# Out:
# Melhores hiperparâmetros: {'logreg__C': 1, 'logreg__fit_intercept': True, 'logreg__max_iter': 1000, 'logreg__penalty': 'l2', 'logreg__tol': 0.0001}
# Classification report para modelo base com balanceamento smote:
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.934761  0.960000  0.947213      1000
# Não reconhecido   0.411765  0.294737  0.343558        95
#
#        accuracy                       0.902283      1095
#       macro avg   0.673263  0.627368  0.645385      1095
#    weighted avg   0.889387  0.902283  0.894841      1095

# %%
ConfusionMatrixDisplay.from_estimator(grid_search, X_test_smote, y_test, 
                                      values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])
