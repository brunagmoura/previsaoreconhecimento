# %% [markdown]
# ## Variáveis desagregadas (2010 a 2017)

# %% [markdown]
# ### Bibliotecas e bases de dados

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn import metrics
from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics import ConfusionMatrixDisplay

#Estilizar conteúdo
warnings.filterwarnings('ignore')
ConvergenceWarning('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def estilo_tabelas(df, max_altura='300px', casas_decimais=3):
    def cor_linhas(row):
        if row.name % 2 == 0:
            return ['background-color: #ffffff'] * len(row)
        else:
            return ['background-color: #f9f9f9'] * len(row)
    
    return (
        df.style.apply(cor_linhas, axis=1) 
        .set_table_styles(
            [
                {'selector': 'thead th', 'props': [('font-size', '12px'), ('text-align', 'center'), ('border-bottom', '2px solid #007BFF')]},  # Azul abaixo do nome das colunas
                {'selector': 'td', 'props': [('font-size', '10px'), ('text-align', 'center'), ('max-height', '40px'), ('white-space', 'nowrap'), ('text-overflow', 'ellipsis'), ('overflow', 'hidden'), ('max-width', '300px')]},
                {'selector': 'table', 'props': [('width', '90%'), ('margin-left', 'auto'), ('margin-right', 'auto'), ('border-collapse', 'collapse')]},
                {'selector': 'td, th', 'props': [('border', '1px solid #666')]},
            ]
        )
        .set_properties(
            **{'border-color': 'darkgray', 'border-style': 'solid', 'border-width': '1px'}
        )
        .set_table_attributes(
            f'style="height:auto; overflow:auto; max-height:{max_altura}; display:block;"'  
        )
        .format(
            precision=casas_decimais  
        )
    )

# Base de dados

df_eventos_2010_2017_modelo2 = pd.read_csv(
    "https://raw.githubusercontent.com/brunagmoura/PrevisorReconhecimento/refs/heads/main/df_eventos_2010_2017_modelo2.csv",
    sep=';',
    decimal=',',
)

# %% [markdown]
# ### Ajustes da base de dados

# %%
# Remover linhas com dados ausentes

df_eventos_2010_2017_modelo2 = df_eventos_2010_2017_modelo2.dropna()

estilo_tabelas(df_eventos_2010_2017_modelo2.head(5))
# Out:
# <style type="text/css">
# #T_f7632 thead th {
#   font-size: 12px;
#   text-align: center;
#   border-bottom: 2px solid #007BFF;
# }
# #T_f7632 td {
#   font-size: 10px;
#   text-align: center;
#   max-height: 40px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   max-width: 300px;
# }
# #T_f7632 table {
#   width: 90%;
#   margin-left: auto;
#   margin-right: auto;
#   border-collapse: collapse;
# }
# #T_f7632 td {
#   border: 1px solid #666;
# }
# #T_f7632  th {
#   border: 1px solid #666;
# }
# #T_f7632_row0_col0, #T_f7632_row0_col1, #T_f7632_row0_col2, #T_f7632_row0_col3, #T_f7632_row0_col4, #T_f7632_row0_col5, #T_f7632_row0_col6, #T_f7632_row0_col7, #T_f7632_row0_col8, #T_f7632_row0_col9, #T_f7632_row0_col10, #T_f7632_row0_col11, #T_f7632_row0_col12, #T_f7632_row0_col13, #T_f7632_row0_col14, #T_f7632_row0_col15, #T_f7632_row0_col16, #T_f7632_row0_col17, #T_f7632_row0_col18, #T_f7632_row0_col19, #T_f7632_row0_col20, #T_f7632_row0_col21, #T_f7632_row0_col22, #T_f7632_row0_col23, #T_f7632_row0_col24, #T_f7632_row0_col25, #T_f7632_row0_col26, #T_f7632_row0_col27, #T_f7632_row0_col28, #T_f7632_row0_col29, #T_f7632_row0_col30, #T_f7632_row0_col31, #T_f7632_row0_col32, #T_f7632_row0_col33, #T_f7632_row0_col34, #T_f7632_row0_col35, #T_f7632_row0_col36, #T_f7632_row0_col37, #T_f7632_row0_col38, #T_f7632_row0_col39, #T_f7632_row0_col40, #T_f7632_row0_col41, #T_f7632_row0_col42, #T_f7632_row0_col43, #T_f7632_row0_col44, #T_f7632_row0_col45, #T_f7632_row0_col46, #T_f7632_row0_col47, #T_f7632_row0_col48, #T_f7632_row0_col49, #T_f7632_row0_col50, #T_f7632_row0_col51, #T_f7632_row0_col52, #T_f7632_row0_col53, #T_f7632_row0_col54, #T_f7632_row0_col55, #T_f7632_row0_col56, #T_f7632_row0_col57, #T_f7632_row0_col58, #T_f7632_row0_col59, #T_f7632_row0_col60, #T_f7632_row0_col61, #T_f7632_row0_col62, #T_f7632_row0_col63, #T_f7632_row0_col64, #T_f7632_row0_col65, #T_f7632_row0_col66, #T_f7632_row0_col67, #T_f7632_row0_col68, #T_f7632_row0_col69, #T_f7632_row0_col70, #T_f7632_row0_col71, #T_f7632_row0_col72, #T_f7632_row0_col73, #T_f7632_row0_col74, #T_f7632_row0_col75, #T_f7632_row0_col76, #T_f7632_row0_col77, #T_f7632_row0_col78, #T_f7632_row0_col79, #T_f7632_row0_col80, #T_f7632_row0_col81, #T_f7632_row0_col82, #T_f7632_row0_col83, #T_f7632_row0_col84, #T_f7632_row0_col85, #T_f7632_row0_col86, #T_f7632_row0_col87, #T_f7632_row0_col88, #T_f7632_row0_col89, #T_f7632_row0_col90, #T_f7632_row0_col91, #T_f7632_row0_col92, #T_f7632_row0_col93, #T_f7632_row0_col94, #T_f7632_row0_col95, #T_f7632_row0_col96, #T_f7632_row0_col97, #T_f7632_row0_col98, #T_f7632_row0_col99, #T_f7632_row0_col100, #T_f7632_row0_col101, #T_f7632_row0_col102, #T_f7632_row0_col103, #T_f7632_row0_col104, #T_f7632_row0_col105, #T_f7632_row0_col106, #T_f7632_row0_col107, #T_f7632_row0_col108, #T_f7632_row0_col109, #T_f7632_row0_col110, #T_f7632_row0_col111, #T_f7632_row0_col112, #T_f7632_row0_col113, #T_f7632_row0_col114, #T_f7632_row0_col115, #T_f7632_row0_col116, #T_f7632_row1_col0, #T_f7632_row1_col1, #T_f7632_row1_col2, #T_f7632_row1_col3, #T_f7632_row1_col4, #T_f7632_row1_col5, #T_f7632_row1_col6, #T_f7632_row1_col7, #T_f7632_row1_col8, #T_f7632_row1_col9, #T_f7632_row1_col10, #T_f7632_row1_col11, #T_f7632_row1_col12, #T_f7632_row1_col13, #T_f7632_row1_col14, #T_f7632_row1_col15, #T_f7632_row1_col16, #T_f7632_row1_col17, #T_f7632_row1_col18, #T_f7632_row1_col19, #T_f7632_row1_col20, #T_f7632_row1_col21, #T_f7632_row1_col22, #T_f7632_row1_col23, #T_f7632_row1_col24, #T_f7632_row1_col25, #T_f7632_row1_col26, #T_f7632_row1_col27, #T_f7632_row1_col28, #T_f7632_row1_col29, #T_f7632_row1_col30, #T_f7632_row1_col31, #T_f7632_row1_col32, #T_f7632_row1_col33, #T_f7632_row1_col34, #T_f7632_row1_col35, #T_f7632_row1_col36, #T_f7632_row1_col37, #T_f7632_row1_col38, #T_f7632_row1_col39, #T_f7632_row1_col40, #T_f7632_row1_col41, #T_f7632_row1_col42, #T_f7632_row1_col43, #T_f7632_row1_col44, #T_f7632_row1_col45, #T_f7632_row1_col46, #T_f7632_row1_col47, #T_f7632_row1_col48, #T_f7632_row1_col49, #T_f7632_row1_col50, #T_f7632_row1_col51, #T_f7632_row1_col52, #T_f7632_row1_col53, #T_f7632_row1_col54, #T_f7632_row1_col55, #T_f7632_row1_col56, #T_f7632_row1_col57, #T_f7632_row1_col58, #T_f7632_row1_col59, #T_f7632_row1_col60, #T_f7632_row1_col61, #T_f7632_row1_col62, #T_f7632_row1_col63, #T_f7632_row1_col64, #T_f7632_row1_col65, #T_f7632_row1_col66, #T_f7632_row1_col67, #T_f7632_row1_col68, #T_f7632_row1_col69, #T_f7632_row1_col70, #T_f7632_row1_col71, #T_f7632_row1_col72, #T_f7632_row1 ...
#   background-color: #ffffff;
#   border-color: darkgray;
#   border-style: solid;
#   border-width: 1px;
# }
# #T_f7632_row2_col0, #T_f76

# %% [markdown]
# ### Treino e teste

# %%
X_2010_2017_modelo2 = df_eventos_2010_2017_modelo2.drop('Status', axis=1)

y_2010_2017_modelo2 = df_eventos_2010_2017_modelo2['Status']

X_train_2010_2017_modelo2, X_test_2010_2017_modelo2, y_train_2010_2017_modelo2, y_test_2010_2017_modelo2 = train_test_split(X_2010_2017_modelo2, y_2010_2017_modelo2, test_size=0.2, random_state=1, stratify=y_2010_2017_modelo2)

# %% [markdown]
# ### Resultados - sem balanceamento

# %%
#Supress warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
    os.environ["PYTHONWARNINGS"] = "ignore" # Also affect subprocesses
    
# Criar pipeline com normalização e modelo de Regressão Logística
pipeline_2010_2017_modelo2 = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(random_state=1, solver='lbfgs'))
])

# Definir hiperparâmetros para o Grid Search
param_grid_2010_2017_modelo2 = {
    'logreg__C': [0.01, 0.1, 1, 10],  # Regularização
    'logreg__max_iter': [1000],  # Número máximo de iterações
    'logreg__fit_intercept': [True, False],  # Se deve ajustar o intercepto
    'logreg__tol': [1e-4, 1e-3],  # Tolerância para convergência
    'logreg__penalty': ['l1', 'l2'],  # Tipos de penalidade
    'logreg__solver': ['saga'],
}

# Grid Search com validação cruzada
grid_search_2010_2017_modelo2 = GridSearchCV(pipeline_2010_2017_modelo2, param_grid_2010_2017_modelo2, cv=2, scoring='f1_weighted', n_jobs=-1)

grid_search_2010_2017_modelo2.fit(X_train_2010_2017_modelo2, y_train_2010_2017_modelo2)

# Melhor modelo encontrado
logreg_best_2010_2017_modelo2 = grid_search_2010_2017_modelo2.best_estimator_

print(f"Melhores hiperparâmetros: {grid_search_2010_2017_modelo2.best_params_}")

# F1 score no conjunto de teste
y_pred_2010_2017_modelo2 = logreg_best_2010_2017_modelo2.predict(X_test_2010_2017_modelo2)

f1_2010_2017_modelo2 = f1_score(y_test_2010_2017_modelo2, y_pred_2010_2017_modelo2, average='weighted')
print(f"F1 Score: {f1_2010_2017_modelo2:.6f}")

classification_report_2010_2017_modelo2 = metrics.classification_report(y_test_2010_2017_modelo2, y_pred_2010_2017_modelo2, digits=6, target_names=['Reconhecido', 'Não reconhecido'])
print('Classification report para modelo 2 (2010 - 2017): \n')
print(classification_report_2010_2017_modelo2)
# Out:
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Melhores hiperparâmetros: {'logreg__C': 1, 'logreg__fit_intercept': True, 'logreg__max_iter': 1000, 'logreg__penalty': 'l1', 'logreg__solver': 'saga', 'logreg__tol': 0.0001}
# F1 Score: 0.875857
# Classification report para modelo 2 (2010 - 2017):
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.915284  0.987220  0.949892      1565
# Não reconhecido   0.375000  0.077419  0.128342       155
#
#        accuracy                       0.905233      1720
#       macro avg   0.645142  0.532320  0.539117      1720
#    weighted avg   0.866596  0.905233  0.875857      1720

# %%
ConfusionMatrixDisplay.from_estimator(grid_search_2010_2017_modelo2, X_test_2010_2017_modelo2, y_test_2010_2017_modelo2, 
                                      values_format='d', cmap='Blues', display_labels=['Reconhecido', 'Não reconhecido'])

# %% [markdown]
# ### Resultados - com balanceamento SMOTE

# %%
#Supress warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
    os.environ["PYTHONWARNINGS"] = "ignore" # Also affect subprocesses
    
smote = SMOTE(random_state=1)
X_train_smote_2010_2017_modelo2, y_train_smote_2010_2017_modelo2 = smote.fit_resample(X_train_2010_2017_modelo2, y_train_2010_2017_modelo2)

pipeline_2010_2017_modelo2 = Pipeline([
    ('scaler', StandardScaler()), 
    ('logreg', LogisticRegression(random_state=1, solver='lbfgs'))  
])

# Definir hiperparâmetros para o Grid Search
param_grid_2010_2017_modelo2 = {
    'logreg__C': [0.01, 0.1, 1, 10],  # Regularização
    'logreg__max_iter': [1000],  # Número máximo de iterações
    'logreg__fit_intercept': [True, False],  # Se deve ajustar o intercepto
    'logreg__tol': [1e-4, 1e-3],  # Tolerância para convergência
    'logreg__penalty': ['l1', 'l2'],  # Tipos de penalidade
    'logreg__solver': ['saga'],
}

# Grid Search com validação cruzada
grid_search_2010_2017_modelo2 = GridSearchCV(pipeline_2010_2017_modelo2, param_grid_2010_2017_modelo2, cv=3, scoring='f1_weighted', n_jobs=-1)

# Treinar o pipeline com Grid Search
grid_search_2010_2017_modelo2.fit(X_train_smote_2010_2017_modelo2, y_train_smote_2010_2017_modelo2)

# Melhor modelo encontrado
logreg_best_2010_2017_modelo2 = grid_search_2010_2017_modelo2.best_estimator_

print(f"Melhores hiperparâmetros: {grid_search_2010_2017_modelo2.best_params_}")

# F1 score no conjunto de teste
y_pred_2010_2017_modelo2_smote = logreg_best_2010_2017_modelo2.predict(X_test_2010_2017_modelo2)

f1_smote_2010_2017_modelo2 = f1_score(y_test_2010_2017_modelo2, y_pred_2010_2017_modelo2_smote, average='weighted')
print(f"F1 Score: {f1_smote_2010_2017_modelo2:.2f}")

classification_report_smote_2010_2017_modelo2 = metrics.classification_report(y_test_2010_2017_modelo2, y_pred_2010_2017_modelo2_smote, digits=6, target_names=['Reconhecido', 'Não reconhecido'])
print('Classification report para modelo 3 com smote (2010 - 2017): \n')
print(classification_report_smote_2010_2017_modelo2)
# Out:
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/brunamoura/PrevisorReconhecimento/.venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Melhores hiperparâmetros: {'logreg__C': 10, 'logreg__fit_intercept': True, 'logreg__max_iter': 1000, 'logreg__penalty': 'l2', 'logreg__solver': 'saga', 'logreg__tol': 0.0001}
# F1 Score: 0.80
# Classification report para modelo 3 com smote (2010 - 2017):
#
#                  precision    recall  f1-score   support
#
#     Reconhecido   0.951181  0.771885  0.852205      1565
# Não reconhecido   0.206667  0.600000  0.307438       155
#
#        accuracy                       0.756395      1720
#       macro avg   0.578924  0.685942  0.579821      1720
#    weighted avg   0.884088  0.756395  0.803112      1720
